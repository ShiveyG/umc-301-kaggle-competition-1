# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/xgboost_model/pytorch/default/1/xgboost_model.pkl
# /kaggle/input/catboost_model/pytorch/default/1/catboost_model.pkl
# /kaggle/input/lightgbm_model/pytorch/default/1/lightgbm_model.pkl
# /kaggle/input/iisc-umc-301-kaggle-competition-1/sample_submission.csv
# /kaggle/input/iisc-umc-301-kaggle-competition-1/train.csv
# /kaggle/input/iisc-umc-301-kaggle-competition-1/test.csv

# %%
import xgboost as xgb
from catboost import CatBoostClassifier
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedKFold
from sklearn.impute import KNNImputer, SimpleImputer
from sklearn.model_selection import KFold
import optuna
from sklearn.preprocessing import LabelEncoder

# %%
train_df = pd.read_csv('/kaggle/input/iisc-umc-301-kaggle-competition-1/train.csv')
test_df = pd.read_csv('/kaggle/input/iisc-umc-301-kaggle-competition-1/test.csv')

# %%
X = train_df.drop(['id', 'song_popularity'], axis=1)
y = train_df['song_popularity']
X_test = test_df.drop('id', axis=1)

print(X.shape, y.shape, X_test.shape)

test_ids = test_df['id']
# Out:
# (30000, 13) (30000,) (10000, 13)

# %%
X_train = X
y_train = y

# %%
# KNN Imputation Function
def knn_impute(X_train, X_test, n_neighbors=5):
    # Combine train + test for consistent encoding + imputation
    combined = pd.concat([X_train, X_test], axis=0, ignore_index=True)

    # Separate categorical and numerical columns
    cat_cols = combined.select_dtypes(include=['object', 'category']).columns
    num_cols = combined.select_dtypes(include=['number']).columns

    # Encode categorical features
    encoders = {}
    for col in cat_cols:
        le = LabelEncoder()
        # Handle missing
        combined[col] = combined[col].astype(str)
        combined[col] = combined[col].replace("nan", pd.NA)
        combined[col] = combined[col].fillna("MISSING")
        combined[col] = le.fit_transform(combined[col])
        encoders[col] = le

    
    imputer = KNNImputer(n_neighbors=n_neighbors, weights="uniform")
    imputed_data = imputer.fit_transform(combined)

    
    imputed_df = pd.DataFrame(imputed_data, columns=combined.columns)

    
    for col in cat_cols:
        le = encoders[col]
        imputed_df[col] = imputed_df[col].round().astype(int)  # round float to int
        imputed_df[col] = le.inverse_transform(imputed_df[col])

    
    imputed_train = imputed_df.iloc[:len(X_train), :].reset_index(drop=True)
    imputed_test = imputed_df.iloc[len(X_train):, :].reset_index(drop=True)

    return imputed_train, imputed_test


X_train_imputed, X_test_imputed = knn_impute(X_train, X_test, n_neighbors=5)

# %%
#Check if any missing values remain
X_train_imputed.isna().sum()
# Out:
# song_duration_ms    0
# acousticness        0
# danceability        0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# audio_mode          0
# speechiness         0
# tempo               0
# time_signature      0
# audio_valence       0
# dtype: int64

# %%
#Optuna Objective Function for XGBoost for Hyperparameter Tuning

def objective_xgb(trial):
    params = {
        "objective": "binary:logistic",
        "eval_metric": "auc",
        "booster": "gbtree",
        "tree_method": "hist",
        "device" : "cuda",
        "random_state": 42,

        # Search space
        "eta": trial.suggest_float("eta", 0.01, 0.3, log=True),
        "max_depth": trial.suggest_int("max_depth", 3, 10),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 10),
        "subsample": trial.suggest_float("subsample", 0.5, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1.0),
        "gamma": trial.suggest_float("gamma", 0, 5),
        "lambda": trial.suggest_float("lambda", 1e-3, 10.0, log=True),  # L2
        "alpha": trial.suggest_float("alpha", 1e-3, 10.0, log=True)     # L1
    }

    kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    aucs = []

    for train_idx, val_idx in kf.split(X_train_imputed, y):
        X_tr, X_val = X_train_imputed.iloc[train_idx], X_train_imputed.iloc[val_idx]
        y_tr, y_val = y.iloc[train_idx], y.iloc[val_idx]

        dtrain = xgb.DMatrix(X_tr, label=y_tr)
        dval = xgb.DMatrix(X_val, label=y_val)

        model = xgb.train(
            params,
            dtrain,
            num_boost_round=2000,
            evals=[(dval, "validation")],
            early_stopping_rounds=100,
            verbose_eval=False
        )

        preds = model.predict(dval)
        aucs.append(roc_auc_score(y_val, preds))

    return sum(aucs) / len(aucs)

# %%
study_xgb = optuna.create_study(direction="maximize")
study_xgb.optimize(objective_xgb, n_trials=50)
print("Best params XGB:", study_xgb.best_params)
xgb_best_params = study_xgb.best_params
# Out:
# [I 2025-09-24 05:22:02,073] A new study created in memory with name: no-name-12a95e1a-c1b3-4a6f-b8f5-59c59647a529
# [I 2025-09-24 05:22:03,909] Trial 0 finished with value: 0.5608436288249685 and parameters: {'eta': 0.2868266411134794, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 0.5789873150730352, 'colsample_bytree': 0.5767779123224004, 'gamma': 2.9299336173840738, 'lambda': 9.986921374118948, 'alpha': 3.070989456982558}. Best is trial 0 with value: 0.5608436288249685.
# [I 2025-09-24 05:22:06,238] Trial 1 finished with value: 0.5713267625520043 and parameters: {'eta': 0.04997558672583577, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 0.9639044721860399, 'colsample_bytree': 0.6793852932055418, 'gamma': 3.262065114324999, 'lambda': 0.007349247245322492, 'alpha': 0.03349455785974895}. Best is trial 1 with value: 0.5713267625520043.
# [I 2025-09-24 05:22:09,120] Trial 2 finished with value: 0.5723466007930321 and parameters: {'eta': 0.01991777529091761, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.619481038602939, 'colsample_bytree': 0.9023842347756899, 'gamma': 4.091915138828503, 'lambda': 0.7963651314807447, 'alpha': 2.4579128031073703}. Best is trial 2 with value: 0.5723466007930321.
# [I 2025-09-24 05:22:12,547] Trial 3 finished with value: 0.5699462656835959 and parameters: {'eta': 0.01372147523937698, 'max_depth': 6, 'min_child_weight': 1, 'subsample': 0.645804551085986, 'colsample_bytree': 0.5906143327238755, 'gamma': 2.2167412086499882, 'lambda': 0.5170453983299098, 'alpha': 0.3828080430977753}. Best is trial 2 with value: 0.5723466007930321.
# [I 2025-09-24 05:22:15,564] Trial 4 finished with value: 0.5292285698978615 and parameters: {'eta': 0.2790429997179389, 'max_depth': 10, 'min_child_weight': 8, 'subsample': 0.596392889993806, 'colsample_bytree': 0.9531979800170328, 'gamma': 0.7594230431823706, 'lambda': 0.12020256081530209, 'alpha': 2.3706463913163582}. Best is trial 2 with value: 0.5723466007930321.
# [I 2025-09-24 05:22:17,190] Trial 5 finished with value: 0.5497276433075109 and parameters: {'eta': 0.09701508002431919, 'max_depth': 9, 'min_child_weight': 5, 'subsample': 0.9819767269105633, 'colsample_bytree': 0.6306787453425646, 'gamma': 2.4021463575256528, 'lambda': 0.01081200963693979, 'alpha': 0.005590027906320788}. Best is trial 2 with value: 0.5723466007930321.
# [I 2025-09-24 05:22:19,233] Trial 6 finished with value: 0.5396917021389959 and parameters: {'eta': 0.167216793966822, 'max_depth': 8, 'min_child_weight': 8, 'subsample': 0.5432729559113334, 'colsample_bytree': 0.9405223556553968, 'gamma': 2.402835224128314, 'lambda': 0.08792344354967159, 'alpha': 0.004269204835136615}. Best is trial 2 with value: 0.5723466007930321.
# [I 2025-09-24 05:22:23,298] Trial 7 finished with value: 0.5658945495876706 and parameters: {'eta': 0.010596774798767535, 'max_depth': 7, 'min_child_weight': 7, 'subsample': 0.931126528798755, 'colsample_bytree': 0.7595941670028514, 'gamma': 1.1854508495998557, 'lambda': 0.0032121105978320306, 'alpha': 0.26405280328840974}. Best is trial 2 with value: 0.5723466007930321.
# [I 2025-09-24 05:22:24,708] Trial 8 finished with value: 0.5677401122837707 and parameters: {'eta': 0.08613688333697572, 'max_depth': 5, 'min_child_weight': 5, 'subsample': 0.5846688485582101, 'colsample_bytree': 0.6856204840434041, 'gamma': 4.14668520477778, 'lambda': 0.0018876078630714582, 'alpha': 2.8184979997310937}. Best is trial 2 with value: 0.5723466007930321.
# [I 2025-09-24 05:22:28,619] Trial 9 finished with value: 0.5727701834829458 and parameters: {'eta': 0.02335849285918488, 'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.7713950654297043, 'colsample_bytree': 0.5564682578074661, 'gamma': 2.5725403215089755, 'lambda': 0.9612602800117419, 'alpha': 0.07932955426442193}. Best is trial 9 with value: 0.5727701834829458.
# [I 2025-09-24 05:22:30,912] Trial 10 finished with value: 0.572369250177766 and parameters: {'eta': 0.031599332244057504, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 0.8079139400128834, 'colsample_bytree': 0.514030550549545, 'gamma': 0.21131455206164418, 'lambda': 6.558982867762108, 'alpha': 0.028906532496055272}. Best is trial 9 with value: 0.5727701834829458.
# [I 2025-09-24 05:22:33,741] Trial 11 finished with value: 0.5719209761280644 and parameters: {'eta': 0.03127348090786142, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 0.805989984116667, 'colsample_bytree': 0.5107367613163141, 'gamma': 0.08360685020630787, 'lambda': 9.79783304042111, 'alpha': 0.023563786435428887}. Best is trial 9 with value: 0.5727701834829458.
# [I 2025-09-24 05:22:36,695] Trial 12 finished with value: 0.5713591535858417 and parameters: {'eta': 0.02900489155180488, 'max_depth': 4, 'min_child_weight': 10, 'subsample': 0.790400769389318, 'colsample_bytree': 0.5142241215834417, 'gamma': 1.4852090194186311, 'lambda': 1.886772661515757, 'alpha': 0.055471752635751874}. Best is trial 9 with value: 0.5727701834829458.
# [I 2025-09-24 05:22:39,118] Trial 13 finished with value: 0.5739464662118198 and parameters: {'eta': 0.046541262043125975, 'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.7152458479019418, 'colsample_bytree': 0.7664791561705949, 'gamma': 4.831132594660023, 'lambda': 2.78695701133032, 'alpha': 0.1749431723443901}. Best is trial 13 with value: 0.5739464662118198.
# [I 2025-09-24 05:22:41,109] Trial 14 finished with value: 0.573938072707045 and parameters: {'eta': 0.05018410723602585, 'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.6989060694616992, 'colsample_bytree': 0.802268778183996, 'gamma': 4.979116697095192, 'lambda': 0.186686959475201, 'alpha': 0.2934024902319778}. Best is trial 13 with value: 0.5739464662118198.
# [I 2025-09-24 05:22:43,805] Trial 15 finished with value: 0.5699546496467669 and parameters: {'eta': 0.05646002284236699, 'max_depth': 6, 'min_child_weight': 1, 'subsample': 0.6770153528232824, 'colsample_bytree': 0.8085847980553946, 'gamma': 4.984947152113466, 'lambda': 0.11384609902767089, 'alpha': 0.386840003161879}. Best is trial 13 with value: 0.5739464662118198.
# [I 2025-09-24 05:22:45,787] Trial 16 finished with value: 0.5709269894906059 and parameters: {'eta': 0.06037050058499866, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.7083212570726638, 'colsample_bytree': 0.8166905702872294, 'gamma': 4.88779798726044, 'lambda': 0.02820041996641901, 'alpha': 0.859997166288995}. Best is trial 13 with value: 0.5739464662118198.
# [I 2025-09-24 05:22:47,782] Trial 17 finished with value: 0.5715391900965331 and parameters: {'eta': 0.11531936594117442, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.8644352769770056, 'colsample_bytree': 0.8673128884635952, 'gamma': 4.078572632573655, 'lambda': 0.27992518305802366, 'alpha': 8.230887802973777}. Best is trial 13 with value: 0.5739464662118198.
# [I 2025-09-24 05:22:50,234] Trial 18 finished with value: 0.5652062412271812 and parameters: {'eta': 0.044685130139925075, 'max_depth': 7, 'min_child_weight': 2, 'subsample': 0.7101303937629428, 'colsample_bytree': 0.7358253179226691, 'gamma': 3.5558859662628293, 'lambda': 2.3672518206225504, 'alpha': 0.17188568971365156}. Best is trial 13 with value: 0.5739464662118198.
# [I 2025-09-24 05:22:51,346] Trial 19 finished with value: 0.5646034028757156 and parameters: {'eta': 0.15492435923382494, 'max_depth': 4, 'min_child_weight': 6, 'subsample': 0.8745450683240988, 'colsample_bytree': 0.8087415092422593, 'gamma': 4.531673888239524, 'lambda': 0.03921974502237241, 'alpha': 0.009196955096420762}. Best is trial 13 with value: 0.5739464662118198.
# [I 2025-09-24 05:22:53,019] Trial 20 finished with value: 0.5673414881493679 and parameters: {'eta': 0.07556989719600166, 'max_depth': 5, 'min_child_weight': 10, 'subsample': 0.720008771287349, 'colsample_bytree': 0.7386670193121195, 'gamma': 3.6216458635176054, 'lambda': 3.943105081205126, 'alpha': 0.0011993635447681247}. Best is trial 13 with value: 0.5739464662118198.
# [I 2025-09-24 05:22:56,493] Trial 21 finished with value: 0.5729852782597178 and parameters: {'eta': 0.021951304501123845, 'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.7557962803517588, 'colsample_bytree': 0.9972142440744922, 'gamma': 4.411621841212119, 'lambda': 1.1680667175851365, 'alpha': 0.11034041092214106}. Best is trial 13 with value: 0.5739464662118198.
# [I 2025-09-24 05:22:59,031] Trial 22 finished with value: 0.5722233305198825 and parameters: {'eta': 0.0388701768787861, 'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.7464704014071646, 'colsample_bytree': 0.8731821700141755, 'gamma': 4.528418712559178, 'lambda': 0.2965011177670586, 'alpha': 0.1347655639019496}. Best is trial 13 with value: 0.5739464662118198.
# [I 2025-09-24 05:23:02,216] Trial 23 finished with value: 0.5725596868177373 and parameters: {'eta': 0.018784690719937158, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.6651481576003739, 'colsample_bytree': 0.9705244035187905, 'gamma': 4.526434605441608, 'lambda': 1.776326405478206, 'alpha': 0.41483210331436465}. Best is trial 13 with value: 0.5739464662118198.
# [I 2025-09-24 05:23:07,642] Trial 24 finished with value: 0.5722148615737249 and parameters: {'eta': 0.013588678049046676, 'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.852964003183063, 'colsample_bytree': 0.9926727685402973, 'gamma': 4.987581630215516, 'lambda': 0.4752424012361442, 'alpha': 0.7107663045504244}. Best is trial 13 with value: 0.5739464662118198.
# [I 2025-09-24 05:23:10,027] Trial 25 finished with value: 0.5704049112004032 and parameters: {'eta': 0.038144424747185254, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 0.5065746694106472, 'colsample_bytree': 0.8421938948779979, 'gamma': 3.762614048789223, 'lambda': 1.059072830503724, 'alpha': 0.9483633832902179}. Best is trial 13 with value: 0.5739464662118198.
# [I 2025-09-24 05:23:12,613] Trial 26 finished with value: 0.5719635847556975 and parameters: {'eta': 0.06717512222844645, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 0.7458600733441622, 'colsample_bytree': 0.7647451720902723, 'gamma': 4.474368103021163, 'lambda': 0.20008388139481023, 'alpha': 0.09271167492585608}. Best is trial 13 with value: 0.5739464662118198.
# [I 2025-09-24 05:23:15,288] Trial 27 finished with value: 0.5695192782034583 and parameters: {'eta': 0.02352019688285386, 'max_depth': 6, 'min_child_weight': 3, 'subsample': 0.687660644702764, 'colsample_bytree': 0.6923571662751297, 'gamma': 3.187947288640848, 'lambda': 3.723273430639943, 'alpha': 0.01563714976605256}. Best is trial 13 with value: 0.5739464662118198.
# [I 2025-09-24 05:23:17,229] Trial 28 finished with value: 0.5700397077061979 and parameters: {'eta': 0.041442894232518485, 'max_depth': 5, 'min_child_weight': 1, 'subsample': 0.6474487191752671, 'colsample_bytree': 0.9103744915477706, 'gamma': 4.214545928775449, 'lambda': 3.5160283876844707, 'alpha': 0.17807483019496953}. Best is trial 13 with value: 0.5739464662118198.
# [I 2025-09-24 05:23:18,727] Trial 29 finished with value: 0.5709187949194803 and parameters: {'eta': 0.12450324191643573, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 0.8360414397270123, 'colsample_bytree': 0.6343736874353298, 'gamma': 4.713042127617112, 'lambda': 0.04628201817986867, 'alpha': 0.058577100115536636}. Best is trial 13 with value: 0.5739464662118198.
# [I 2025-09-24 05:23:22,498] Trial 30 finished with value: 0.5717901877544035 and parameters: {'eta': 0.01851555902376763, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.8972263618953249, 'colsample_bytree': 0.783987355266316, 'gamma': 3.7782227479858865, 'lambda': 0.5411264728247066, 'alpha': 1.376972915021645}. Best is trial 13 with value: 0.5739464662118198.
# [I 2025-09-24 05:23:26,356] Trial 31 finished with value: 0.5732792419577175 and parameters: {'eta': 0.02502737991152008, 'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.7617899832757975, 'colsample_bytree': 0.7113380489425001, 'gamma': 2.7968696510544286, 'lambda': 0.9570369077446875, 'alpha': 0.07852465715680611}. Best is trial 13 with value: 0.5739464662118198.
# [I 2025-09-24 05:23:30,228] Trial 32 finished with value: 0.5728116717519652 and parameters: {'eta': 0.02513210801843902, 'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.7627204343173228, 'colsample_bytree': 0.7093327574421909, 'gamma': 1.9153360888361357, 'lambda': 1.4435275807522654, 'alpha': 0.04432099808341457}. Best is trial 13 with value: 0.5739464662118198.
# [I 2025-09-24 05:23:32,745] Trial 33 finished with value: 0.5721217058440147 and parameters: {'eta': 0.048155205251196424, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.7428125072418765, 'colsample_bytree': 0.6509048671438611, 'gamma': 3.2572007961084535, 'lambda': 0.8058134271214056, 'alpha': 0.21033991317850015}. Best is trial 13 with value: 0.5739464662118198.
# [I 2025-09-24 05:23:35,924] Trial 34 finished with value: 0.5731203046950374 and parameters: {'eta': 0.015861576000484653, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.6217256669495294, 'colsample_bytree': 0.724748563532231, 'gamma': 2.9533914404116155, 'lambda': 0.3813068548571416, 'alpha': 0.10342433491027693}. Best is trial 13 with value: 0.5739464662118198.
# [I 2025-09-24 05:23:39,321] Trial 35 finished with value: 0.5726110953548247 and parameters: {'eta': 0.015132052556193938, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.614326890869562, 'colsample_bytree': 0.7196373931610267, 'gamma': 2.940758024229332, 'lambda': 0.33932966277514537, 'alpha': 0.4418649986091879}. Best is trial 13 with value: 0.5739464662118198.
# [I 2025-09-24 05:23:43,437] Trial 36 finished with value: 0.572273847739818 and parameters: {'eta': 0.011339050936239587, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.6335150423443658, 'colsample_bytree': 0.6614822618063239, 'gamma': 2.855939723463503, 'lambda': 0.18410755236040838, 'alpha': 0.01621055857769675}. Best is trial 13 with value: 0.5739464662118198.
# [I 2025-09-24 05:23:49,011] Trial 37 finished with value: 0.5590162735399933 and parameters: {'eta': 0.01489082098096196, 'max_depth': 10, 'min_child_weight': 1, 'subsample': 0.5477410070333801, 'colsample_bytree': 0.7810206181803305, 'gamma': 2.022423367995564, 'lambda': 0.06923745235944712, 'alpha': 0.2666959223317168}. Best is trial 13 with value: 0.5739464662118198.
# [I 2025-09-24 05:23:51,159] Trial 38 finished with value: 0.5678488519218094 and parameters: {'eta': 0.0352634659114883, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 0.6949800363532431, 'colsample_bytree': 0.5940793933537871, 'gamma': 1.691592217503557, 'lambda': 0.5036855500701971, 'alpha': 0.08744717079071321}. Best is trial 13 with value: 0.5739464662118198.
# [I 2025-09-24 05:23:54,593] Trial 39 finished with value: 0.5632526486334095 and parameters: {'eta': 0.02708337688106065, 'max_depth': 9, 'min_child_weight': 4, 'subsample': 0.65302446907133, 'colsample_bytree': 0.8365765181375383, 'gamma': 2.6690243268145313, 'lambda': 0.2056219208738144, 'alpha': 1.394419364156925}. Best is trial 13 with value: 0.5739464662118198.
# [I 2025-09-24 05:23:55,786] Trial 40 finished with value: 0.5573190453356219 and parameters: {'eta': 0.2518889287553444, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.6178532792715344, 'colsample_bytree': 0.718964913221629, 'gamma': 0.5689335852317845, 'lambda': 0.01765388046083197, 'alpha': 0.04125917518190434}. Best is trial 13 with value: 0.5739464662118198.
# [I 2025-09-24 05:23:59,992] Trial 41 finished with value: 0.5730154110430095 and parameters: {'eta': 0.01679383287788355, 'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.7335623874328098, 'colsample_bytree': 0.9207210585966646, 'gamma': 4.313071613878204, 'lambda': 1.1268737900265917, 'alpha': 0.12758472794188502}. Best is trial 13 with value: 0.5739464662118198.
# [I 2025-09-24 05:24:04,223] Trial 42 finished with value: 0.5734584769358246 and parameters: {'eta': 0.01728180122160968, 'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.7263701094373284, 'colsample_bytree': 0.8936501937845638, 'gamma': 4.00930116168491, 'lambda': 2.595213458089744, 'alpha': 0.2834055699068828}. Best is trial 13 with value: 0.5739464662118198.
# [I 2025-09-24 05:24:09,815] Trial 43 finished with value: 0.5731053858799229 and parameters: {'eta': 0.01225188826974332, 'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.7788263751707049, 'colsample_bytree': 0.775242853199144, 'gamma': 3.963650240812643, 'lambda': 2.640842805905995, 'alpha': 0.31274362573870823}. Best is trial 13 with value: 0.5739464662118198.
# [I 2025-09-24 05:24:12,636] Trial 44 finished with value: 0.5732128361645688 and parameters: {'eta': 0.02125369081793023, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.5584339154588587, 'colsample_bytree': 0.8870590433800261, 'gamma': 3.388813567433574, 'lambda': 6.108503682819085, 'alpha': 0.5506100432339166}. Best is trial 13 with value: 0.5739464662118198.
# [I 2025-09-24 05:24:15,159] Trial 45 finished with value: 0.5727577395599482 and parameters: {'eta': 0.051503457922717856, 'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.8156843827345547, 'colsample_bytree': 0.8716921323152884, 'gamma': 3.521205644554921, 'lambda': 7.042691839748922, 'alpha': 0.5101640296043021}. Best is trial 13 with value: 0.5739464662118198.
# [I 2025-09-24 05:24:17,948] Trial 46 finished with value: 0.5735907608951829 and parameters: {'eta': 0.03323848439373086, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.552684058681847, 'colsample_bytree': 0.8925021487303126, 'gamma': 4.77019794760988, 'lambda': 4.88075706450494, 'alpha': 4.37150890941218}. Best is trial 13 with value: 0.5739464662118198.
# [I 2025-09-24 05:24:21,268] Trial 47 finished with value: 0.5707223627885499 and parameters: {'eta': 0.0308166591033959, 'max_depth': 8, 'min_child_weight': 6, 'subsample': 0.517475480650816, 'colsample_bytree': 0.926939727055135, 'gamma': 3.9572161489304336, 'lambda': 2.9093535405728965, 'alpha': 5.5492027899230845}. Best is trial 13 with value: 0.5739464662118198.
# [I 2025-09-24 05:24:24,605] Trial 48 finished with value: 0.56984411251747 and parameters: {'eta': 0.0348784879839982, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9386036091887744, 'colsample_bytree': 0.846746572906474, 'gamma': 4.788854648754592, 'lambda': 5.407951071888049, 'alpha': 3.7228241806868825}. Best is trial 13 with value: 0.5739464662118198.
# [I 2025-09-24 05:24:27,645] Trial 49 finished with value: 0.5732268355761804 and parameters: {'eta': 0.06166549700023286, 'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.5726937505295928, 'colsample_bytree': 0.9504883073852793, 'gamma': 4.705782944698685, 'lambda': 8.479809511279793, 'alpha': 9.825480214804232}. Best is trial 13 with value: 0.5739464662118198.
# Best params XGB: {'eta': 0.046541262043125975, 'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.7152458479019418, 'colsample_bytree': 0.7664791561705949, 'gamma': 4.831132594660023, 'lambda': 2.78695701133032, 'alpha': 0.1749431723443901}

# %%
# Optuna Objective Function for CatBoost for Hyperparameter Tuning

def objective_cat(trial):
    params = {
        "iterations": 2000,
        "loss_function": "Logloss",
        "eval_metric": "AUC",
        "random_seed": 42,
        "task_type": "GPU",    
        "verbose": False,

        # Search space
        "depth": trial.suggest_int("depth", 4, 10),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3, log=True),
        "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1, 10, log=True),
        "bagging_temperature": trial.suggest_float("bagging_temperature", 0.0, 5.0),
        "border_count": trial.suggest_int("border_count", 32, 255),
        "random_strength": trial.suggest_float("random_strength", 0.0, 10.0)
    }

    kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    aucs = []

    for train_idx, val_idx in kf.split(X_train_imputed, y):
        X_tr, X_val = X_train_imputed.iloc[train_idx], X_train_imputed.iloc[val_idx]
        y_tr, y_val = y.iloc[train_idx], y.iloc[val_idx]


        model = CatBoostClassifier(**params)
        model.fit(X_tr, y_tr, eval_set=(X_val, y_val), early_stopping_rounds=100)

        preds = model.predict_proba(X_val)[:, 1]
        aucs.append(roc_auc_score(y_val, preds))

    return sum(aucs) / len(aucs)

# %%
study_cat = optuna.create_study(direction="maximize")
study_cat.optimize(objective_cat, n_trials=50)
print("Best params CatBoost:", study_cat.best_params)
cat_best_params = study_cat.best_params
# Out:
# [I 2025-09-24 05:25:29,807] A new study created in memory with name: no-name-11c6d095-86a1-4468-843e-c717275c1e89
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 05:28:44,027] Trial 0 finished with value: 0.573190953891166 and parameters: {'depth': 10, 'learning_rate': 0.02924997938685539, 'l2_leaf_reg': 1.7994973780371595, 'bagging_temperature': 0.5160752580946026, 'border_count': 87, 'random_strength': 6.207733375940205}. Best is trial 0 with value: 0.573190953891166.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 05:29:18,173] Trial 1 finished with value: 0.5719068867495792 and parameters: {'depth': 5, 'learning_rate': 0.10319680456081194, 'l2_leaf_reg': 2.9127669265893417, 'bagging_temperature': 0.7344874925241451, 'border_count': 48, 'random_strength': 9.609497930364391}. Best is trial 0 with value: 0.573190953891166.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 05:30:36,780] Trial 2 finished with value: 0.5721178743396722 and parameters: {'depth': 6, 'learning_rate': 0.02133129122743994, 'l2_leaf_reg': 1.171535730788244, 'bagging_temperature': 1.2064553838348986, 'border_count': 147, 'random_strength': 3.1766888972588503}. Best is trial 0 with value: 0.573190953891166.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 05:31:28,061] Trial 3 finished with value: 0.5708714559055241 and parameters: {'depth': 7, 'learning_rate': 0.12753993122306628, 'l2_leaf_reg': 2.8458807845344127, 'bagging_temperature': 1.9804058526264046, 'border_count': 66, 'random_strength': 6.654641882829751}. Best is trial 0 with value: 0.573190953891166.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 05:32:24,251] Trial 4 finished with value: 0.5733554569459951 and parameters: {'depth': 6, 'learning_rate': 0.030730842592933436, 'l2_leaf_reg': 1.8196482908442768, 'bagging_temperature': 1.4374991104089534, 'border_count': 60, 'random_strength': 3.016817515857549}. Best is trial 4 with value: 0.5733554569459951.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 05:33:35,902] Trial 5 finished with value: 0.571255985096299 and parameters: {'depth': 7, 'learning_rate': 0.04759840928641875, 'l2_leaf_reg': 2.195955949429726, 'bagging_temperature': 4.944964179194891, 'border_count': 77, 'random_strength': 2.337056926801396}. Best is trial 4 with value: 0.5733554569459951.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 05:34:32,178] Trial 6 finished with value: 0.5748300018661274 and parameters: {'depth': 4, 'learning_rate': 0.03858862058992631, 'l2_leaf_reg': 3.0814425362820606, 'bagging_temperature': 1.8868294094055393, 'border_count': 176, 'random_strength': 1.175617871756417}. Best is trial 6 with value: 0.5748300018661274.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 05:35:22,578] Trial 7 finished with value: 0.5746319962009251 and parameters: {'depth': 4, 'learning_rate': 0.04718693673438696, 'l2_leaf_reg': 1.1536049242051185, 'bagging_temperature': 3.662823941513558, 'border_count': 32, 'random_strength': 8.139374399099939}. Best is trial 6 with value: 0.5748300018661274.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 05:38:06,185] Trial 8 finished with value: 0.5731969913833411 and parameters: {'depth': 8, 'learning_rate': 0.01758025824127553, 'l2_leaf_reg': 2.6738120013449076, 'bagging_temperature': 4.0951501824379895, 'border_count': 89, 'random_strength': 9.875705163249055}. Best is trial 6 with value: 0.5748300018661274.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 05:38:53,655] Trial 9 finished with value: 0.5744319788122108 and parameters: {'depth': 5, 'learning_rate': 0.056156700352052696, 'l2_leaf_reg': 1.0433457693289285, 'bagging_temperature': 2.5397422883518956, 'border_count': 107, 'random_strength': 1.8750508622485407}. Best is trial 6 with value: 0.5748300018661274.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 05:42:07,851] Trial 10 finished with value: 0.5655664996409012 and parameters: {'depth': 10, 'learning_rate': 0.2500193303885745, 'l2_leaf_reg': 6.152478356733585, 'bagging_temperature': 2.918847640383907, 'border_count': 220, 'random_strength': 0.6045066624210333}. Best is trial 6 with value: 0.5748300018661274.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 05:43:55,452] Trial 11 finished with value: 0.5737271798555126 and parameters: {'depth': 4, 'learning_rate': 0.010489136776572984, 'l2_leaf_reg': 6.295349281148075, 'bagging_temperature': 3.513113356834449, 'border_count': 171, 'random_strength': 7.95203190494358}. Best is trial 6 with value: 0.5748300018661274.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 05:44:42,776] Trial 12 finished with value: 0.5767176038278039 and parameters: {'depth': 4, 'learning_rate': 0.0653519914018847, 'l2_leaf_reg': 4.533500125999296, 'bagging_temperature': 3.5000012999587784, 'border_count': 198, 'random_strength': 5.014308358082966}. Best is trial 12 with value: 0.5767176038278039.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 05:45:15,236] Trial 13 finished with value: 0.5737254441053079 and parameters: {'depth': 4, 'learning_rate': 0.08734441537674947, 'l2_leaf_reg': 4.379378177462182, 'bagging_temperature': 2.0365044459609973, 'border_count': 215, 'random_strength': 4.367648334480606}. Best is trial 12 with value: 0.5767176038278039.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 05:45:37,067] Trial 14 finished with value: 0.5706063248974458 and parameters: {'depth': 5, 'learning_rate': 0.2126511252713646, 'l2_leaf_reg': 9.005134978080987, 'bagging_temperature': 0.0413526405358704, 'border_count': 187, 'random_strength': 4.767464383618133}. Best is trial 12 with value: 0.5767176038278039.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 05:47:41,785] Trial 15 finished with value: 0.5735268314682871 and parameters: {'depth': 8, 'learning_rate': 0.07535849661250463, 'l2_leaf_reg': 4.178721138834429, 'bagging_temperature': 3.0634566633377243, 'border_count': 192, 'random_strength': 0.1986310683618524}. Best is trial 12 with value: 0.5767176038278039.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 05:48:11,101] Trial 16 finished with value: 0.5710598036404082 and parameters: {'depth': 6, 'learning_rate': 0.15570151541957075, 'l2_leaf_reg': 4.152936904153032, 'bagging_temperature': 4.571517645622142, 'border_count': 241, 'random_strength': 6.011759552825369}. Best is trial 12 with value: 0.5767176038278039.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 05:49:04,992] Trial 17 finished with value: 0.5747218731813104 and parameters: {'depth': 4, 'learning_rate': 0.038571212318734345, 'l2_leaf_reg': 5.682560433370065, 'bagging_temperature': 2.0472696469257716, 'border_count': 148, 'random_strength': 3.970703719642862}. Best is trial 12 with value: 0.5767176038278039.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 05:49:40,717] Trial 18 finished with value: 0.5734687152282364 and parameters: {'depth': 5, 'learning_rate': 0.07239194725814542, 'l2_leaf_reg': 9.654358021200649, 'bagging_temperature': 3.268121459242491, 'border_count': 253, 'random_strength': 1.3844843381640093}. Best is trial 12 with value: 0.5767176038278039.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 05:54:02,630] Trial 19 finished with value: 0.572790892968041 and parameters: {'depth': 9, 'learning_rate': 0.015371864860421565, 'l2_leaf_reg': 3.4876780819687503, 'bagging_temperature': 4.038940267102115, 'border_count': 124, 'random_strength': 5.429433322747714}. Best is trial 12 with value: 0.5767176038278039.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 05:55:26,559] Trial 20 finished with value: 0.5735360240790747 and parameters: {'depth': 7, 'learning_rate': 0.026755293646590354, 'l2_leaf_reg': 7.403502692944597, 'bagging_temperature': 2.599461183126205, 'border_count': 181, 'random_strength': 3.3459889958032023}. Best is trial 12 with value: 0.5767176038278039.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 05:56:30,602] Trial 21 finished with value: 0.5745079582358992 and parameters: {'depth': 4, 'learning_rate': 0.03976058980173057, 'l2_leaf_reg': 5.1150867161743845, 'bagging_temperature': 1.797302645244574, 'border_count': 153, 'random_strength': 4.0828551922355985}. Best is trial 12 with value: 0.5767176038278039.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 05:57:13,628] Trial 22 finished with value: 0.5732069607157961 and parameters: {'depth': 4, 'learning_rate': 0.06291828477530118, 'l2_leaf_reg': 5.121729288256377, 'bagging_temperature': 2.3853530092855544, 'border_count': 161, 'random_strength': 7.20862903886062}. Best is trial 12 with value: 0.5767176038278039.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 05:58:01,412] Trial 23 finished with value: 0.5748240884742384 and parameters: {'depth': 5, 'learning_rate': 0.03865125883919743, 'l2_leaf_reg': 3.741301221285489, 'bagging_temperature': 1.3338550701975245, 'border_count': 133, 'random_strength': 0.9580160617541655}. Best is trial 12 with value: 0.5767176038278039.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 05:58:52,307] Trial 24 finished with value: 0.5746073713732434 and parameters: {'depth': 5, 'learning_rate': 0.036062752928214786, 'l2_leaf_reg': 3.6188541254064965, 'bagging_temperature': 1.242408240371315, 'border_count': 126, 'random_strength': 1.0121308234779014}. Best is trial 12 with value: 0.5767176038278039.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 05:59:56,534] Trial 25 finished with value: 0.5742033644919843 and parameters: {'depth': 5, 'learning_rate': 0.022658334404399617, 'l2_leaf_reg': 2.2952945932790074, 'bagging_temperature': 1.6570674661160991, 'border_count': 203, 'random_strength': 0.026451664414338216}. Best is trial 12 with value: 0.5767176038278039.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 06:00:43,782] Trial 26 finished with value: 0.5732471641705346 and parameters: {'depth': 6, 'learning_rate': 0.053576932452320924, 'l2_leaf_reg': 3.532220802772198, 'bagging_temperature': 0.7523566329368299, 'border_count': 121, 'random_strength': 2.2318129518416763}. Best is trial 12 with value: 0.5767176038278039.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 06:01:14,577] Trial 27 finished with value: 0.5730417375612331 and parameters: {'depth': 4, 'learning_rate': 0.10725346909150064, 'l2_leaf_reg': 2.3353138681771193, 'bagging_temperature': 1.0800882828179894, 'border_count': 167, 'random_strength': 1.3337021464761536}. Best is trial 12 with value: 0.5767176038278039.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 06:02:48,326] Trial 28 finished with value: 0.5723043917663222 and parameters: {'depth': 5, 'learning_rate': 0.0131657570538154, 'l2_leaf_reg': 1.7374264637310342, 'bagging_temperature': 2.2916632740511735, 'border_count': 230, 'random_strength': 5.211385722459719}. Best is trial 12 with value: 0.5767176038278039.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 06:03:43,431] Trial 29 finished with value: 0.5721335399623821 and parameters: {'depth': 6, 'learning_rate': 0.030351864037458837, 'l2_leaf_reg': 1.5463013319445191, 'bagging_temperature': 0.45613892641608755, 'border_count': 200, 'random_strength': 2.992889430781342}. Best is trial 12 with value: 0.5767176038278039.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 06:04:55,046] Trial 30 finished with value: 0.5742730490317024 and parameters: {'depth': 4, 'learning_rate': 0.02326601975114047, 'l2_leaf_reg': 4.7083863808161155, 'bagging_temperature': 2.8445911132001127, 'border_count': 176, 'random_strength': 6.020243415900992}. Best is trial 12 with value: 0.5767176038278039.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 06:06:03,145] Trial 31 finished with value: 0.5743282168623426 and parameters: {'depth': 4, 'learning_rate': 0.03783450114005715, 'l2_leaf_reg': 6.031819230053387, 'bagging_temperature': 1.5363578373587063, 'border_count': 146, 'random_strength': 4.291345397019595}. Best is trial 12 with value: 0.5767176038278039.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 06:06:51,690] Trial 32 finished with value: 0.5744533082459732 and parameters: {'depth': 5, 'learning_rate': 0.04100103470498141, 'l2_leaf_reg': 7.378671678524061, 'bagging_temperature': 2.0698709824478794, 'border_count': 137, 'random_strength': 3.6526108033982125}. Best is trial 12 with value: 0.5767176038278039.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 06:07:35,017] Trial 33 finished with value: 0.5747312968366789 and parameters: {'depth': 4, 'learning_rate': 0.06831959018478191, 'l2_leaf_reg': 3.2308698357262893, 'bagging_temperature': 0.8885061341088389, 'border_count': 106, 'random_strength': 2.374200860054567}. Best is trial 12 with value: 0.5767176038278039.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 06:08:01,210] Trial 34 finished with value: 0.5716022836581425 and parameters: {'depth': 5, 'learning_rate': 0.099476651147578, 'l2_leaf_reg': 3.1857350585918986, 'bagging_temperature': 0.9624175272800768, 'border_count': 107, 'random_strength': 1.8822823596749814}. Best is trial 12 with value: 0.5767176038278039.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 06:08:35,995] Trial 35 finished with value: 0.5727629740583129 and parameters: {'depth': 4, 'learning_rate': 0.06207574878967144, 'l2_leaf_reg': 2.9934685860681554, 'bagging_temperature': 0.41408315114340166, 'border_count': 93, 'random_strength': 0.7298687412470992}. Best is trial 12 with value: 0.5767176038278039.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 06:09:00,646] Trial 36 finished with value: 0.5725936143850484 and parameters: {'depth': 5, 'learning_rate': 0.15009582100772584, 'l2_leaf_reg': 2.6643427451315937, 'bagging_temperature': 1.3738603049401028, 'border_count': 110, 'random_strength': 2.466041704194856}. Best is trial 12 with value: 0.5767176038278039.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 06:09:40,568] Trial 37 finished with value: 0.5747463218930667 and parameters: {'depth': 4, 'learning_rate': 0.07344031043880199, 'l2_leaf_reg': 3.872873276677893, 'bagging_temperature': 0.7519353930521102, 'border_count': 135, 'random_strength': 2.7566108581837607}. Best is trial 12 with value: 0.5767176038278039.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 06:10:16,942] Trial 38 finished with value: 0.5720988107163796 and parameters: {'depth': 6, 'learning_rate': 0.08650949417994201, 'l2_leaf_reg': 3.881777422307693, 'bagging_temperature': 1.769001214589214, 'border_count': 159, 'random_strength': 1.512348312034626}. Best is trial 12 with value: 0.5767176038278039.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 06:11:18,604] Trial 39 finished with value: 0.5734180058970547 and parameters: {'depth': 7, 'learning_rate': 0.0499625318225265, 'l2_leaf_reg': 2.615157676157246, 'bagging_temperature': 0.6202942425576374, 'border_count': 136, 'random_strength': 2.8808976641391513}. Best is trial 12 with value: 0.5767176038278039.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 06:12:25,965] Trial 40 finished with value: 0.5716244369120951 and parameters: {'depth': 4, 'learning_rate': 0.03181170340821312, 'l2_leaf_reg': 4.921556239784197, 'bagging_temperature': 0.05824602616609331, 'border_count': 207, 'random_strength': 0.8089497664146519}. Best is trial 12 with value: 0.5767176038278039.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 06:13:07,820] Trial 41 finished with value: 0.5729474591209974 and parameters: {'depth': 4, 'learning_rate': 0.06434136903676616, 'l2_leaf_reg': 3.2815877317413435, 'bagging_temperature': 0.813231832118306, 'border_count': 71, 'random_strength': 2.183026648738392}. Best is trial 12 with value: 0.5767176038278039.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 06:13:34,833] Trial 42 finished with value: 0.5750400176603914 and parameters: {'depth': 4, 'learning_rate': 0.12515812414731872, 'l2_leaf_reg': 3.8239300129267457, 'bagging_temperature': 1.3833467887777509, 'border_count': 101, 'random_strength': 2.7726234014162014}. Best is trial 12 with value: 0.5767176038278039.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 06:14:07,398] Trial 43 finished with value: 0.5727573859033703 and parameters: {'depth': 5, 'learning_rate': 0.11753735812215321, 'l2_leaf_reg': 3.804358381794356, 'bagging_temperature': 1.464689766206676, 'border_count': 93, 'random_strength': 1.7175783651032317}. Best is trial 12 with value: 0.5767176038278039.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 06:14:35,825] Trial 44 finished with value: 0.5739434022533215 and parameters: {'depth': 4, 'learning_rate': 0.13832384357094746, 'l2_leaf_reg': 4.466325537818048, 'bagging_temperature': 1.1210470750033457, 'border_count': 81, 'random_strength': 2.8385953434349536}. Best is trial 12 with value: 0.5767176038278039.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 06:14:59,164] Trial 45 finished with value: 0.5729499299589801 and parameters: {'depth': 5, 'learning_rate': 0.17907429518965345, 'l2_leaf_reg': 2.887637818698786, 'bagging_temperature': 1.293016686594973, 'border_count': 45, 'random_strength': 3.458102722556341}. Best is trial 12 with value: 0.5767176038278039.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 06:15:41,885] Trial 46 finished with value: 0.5751186832737653 and parameters: {'depth': 4, 'learning_rate': 0.08277383878853005, 'l2_leaf_reg': 2.059933402055779, 'bagging_temperature': 0.3305780948587158, 'border_count': 132, 'random_strength': 9.088938474589622}. Best is trial 12 with value: 0.5767176038278039.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 06:16:00,395] Trial 47 finished with value: 0.5705803131815766 and parameters: {'depth': 4, 'learning_rate': 0.28466403969610626, 'l2_leaf_reg': 2.0824950476591755, 'bagging_temperature': 0.28494349769429816, 'border_count': 191, 'random_strength': 9.179632121807735}. Best is trial 12 with value: 0.5767176038278039.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 06:16:36,672] Trial 48 finished with value: 0.5742142820592879 and parameters: {'depth': 5, 'learning_rate': 0.09392699076847734, 'l2_leaf_reg': 1.392899702868278, 'bagging_temperature': 3.8685590023524465, 'border_count': 121, 'random_strength': 8.657713741387429}. Best is trial 12 with value: 0.5767176038278039.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2025-09-24 06:17:42,141] Trial 49 finished with value: 0.5756154814498683 and parameters: {'depth': 6, 'learning_rate': 0.04561230856058529, 'l2_leaf_reg': 1.7595578544663266, 'bagging_temperature': 4.860530477410666, 'border_count': 219, 'random_strength': 7.717516973036643}. Best is trial 12 with value: 0.5767176038278039.
# Best params CatBoost: {'depth': 4, 'learning_rate': 0.0653519914018847, 'l2_leaf_reg': 4.533500125999296, 'bagging_temperature': 3.5000012999587784, 'border_count': 198, 'random_strength': 5.014308358082966}

# %%
# Optuna Objective Function for LightGBM for Hyperparameter Tuning

def objective(trial):
    params = {
        "objective": "binary",
        "metric": "auc",
        "boosting_type": "gbdt",
        "verbosity": -1,
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3, log=True),
        "num_leaves": trial.suggest_int("num_leaves", 16, 256),
        "max_depth": trial.suggest_int("max_depth", 3, 12),
        "min_child_samples": trial.suggest_int("min_child_samples", 10, 100),
        "subsample": trial.suggest_float("subsample", 0.5, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1.0),
        "reg_alpha": trial.suggest_float("reg_alpha", 1e-8, 10.0, log=True),
        "reg_lambda": trial.suggest_float("reg_lambda", 1e-8, 10.0, log=True),
        "min_split_gain": trial.suggest_float("min_split_gain", 0.0, 1.0),
        "n_estimators": 2000,
        "device": "gpu"
    }

    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    aucs = []

    for train_idx, val_idx in cv.split(X_train_imputed, y):
        X_tr, X_val = X.iloc[train_idx], X.iloc[val_idx]
        y_tr, y_val = y.iloc[train_idx], y.iloc[val_idx]

        model = lgb.LGBMClassifier(**params)
        model.fit(
            X_tr, y_tr,
            eval_set=[(X_val, y_val)],
            eval_metric="auc",
        )
        preds = model.predict_proba(X_val)[:, 1]
        aucs.append(roc_auc_score(y_val, preds))

    return np.mean(aucs)

# Run Optuna
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=50) 

print("Best trial:", study.best_trial.params)
print("Best AUC:", study.best_value)
# Out:
# [I 2025-09-24 06:20:22,724] A new study created in memory with name: no-name-653246f6-cab1-47e8-b874-f7c171a56f4f
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# [I 2025-09-24 06:20:39,269] Trial 0 finished with value: 0.5467089101629585 and parameters: {'learning_rate': 0.16921750760498647, 'num_leaves': 81, 'max_depth': 5, 'min_child_samples': 89, 'subsample': 0.6369770647558126, 'colsample_bytree': 0.5136933014998049, 'reg_alpha': 0.0035501638752162843, 'reg_lambda': 0.0018769776781935857, 'min_split_gain': 0.18739595146995425}. Best is trial 0 with value: 0.5467089101629585.
# [I 2025-09-24 06:20:49,624] Trial 1 finished with value: 0.5574028398162978 and parameters: {'learning_rate': 0.18351965022435784, 'num_leaves': 125, 'max_depth': 5, 'min_child_samples': 93, 'subsample': 0.5435050332118655, 'colsample_bytree': 0.8735178147870959, 'reg_alpha': 0.44962786034799956, 'reg_lambda': 6.601937597162703e-07, 'min_split_gain': 0.39972873264896225}. Best is trial 1 with value: 0.5574028398162978.
# [I 2025-09-24 06:21:04,074] Trial 2 finished with value: 0.5698565177771546 and parameters: {'learning_rate': 0.02086692816176144, 'num_leaves': 145, 'max_depth': 4, 'min_child_samples': 61, 'subsample': 0.681832208618331, 'colsample_bytree': 0.7988606294865446, 'reg_alpha': 1.590253706526704e-05, 'reg_lambda': 5.343367951304898, 'min_split_gain': 0.6998143103360418}. Best is trial 2 with value: 0.5698565177771546.
# [I 2025-09-24 06:21:27,905] Trial 3 finished with value: 0.5644987107056704 and parameters: {'learning_rate': 0.010375287827844113, 'num_leaves': 118, 'max_depth': 4, 'min_child_samples': 75, 'subsample': 0.6054996814714879, 'colsample_bytree': 0.927849357682055, 'reg_alpha': 0.44859471946817975, 'reg_lambda': 1.8037691702098807e-08, 'min_split_gain': 0.4143486188517398}. Best is trial 2 with value: 0.5698565177771546.
# [I 2025-09-24 06:21:39,369] Trial 4 finished with value: 0.5686835743360957 and parameters: {'learning_rate': 0.03952193846703528, 'num_leaves': 43, 'max_depth': 4, 'min_child_samples': 57, 'subsample': 0.9822331182200561, 'colsample_bytree': 0.8223125484001363, 'reg_alpha': 0.00014970101863440453, 'reg_lambda': 0.05081757015823867, 'min_split_gain': 0.944762000152493}. Best is trial 2 with value: 0.5698565177771546.
# [I 2025-09-24 06:22:01,243] Trial 5 finished with value: 0.5658171145780816 and parameters: {'learning_rate': 0.012568239759666868, 'num_leaves': 30, 'max_depth': 10, 'min_child_samples': 29, 'subsample': 0.9641475376053155, 'colsample_bytree': 0.8411247008271515, 'reg_alpha': 8.729847100518122e-06, 'reg_lambda': 0.00044725329654041125, 'min_split_gain': 0.9417807164846296}. Best is trial 2 with value: 0.5698565177771546.
# [I 2025-09-24 06:23:41,699] Trial 6 finished with value: 0.549486836159079 and parameters: {'learning_rate': 0.011784979591683726, 'num_leaves': 213, 'max_depth': 11, 'min_child_samples': 15, 'subsample': 0.915159648474688, 'colsample_bytree': 0.5374055007046239, 'reg_alpha': 3.793810882900545e-08, 'reg_lambda': 0.011813282783364968, 'min_split_gain': 0.10835679743137194}. Best is trial 2 with value: 0.5698565177771546.
# [I 2025-09-24 06:23:53,807] Trial 7 finished with value: 0.5656831338375209 and parameters: {'learning_rate': 0.054168486947312924, 'num_leaves': 190, 'max_depth': 5, 'min_child_samples': 80, 'subsample': 0.7666049776163049, 'colsample_bytree': 0.6314435389433153, 'reg_alpha': 4.737921262158464e-07, 'reg_lambda': 6.200338424463654e-07, 'min_split_gain': 0.4814184681456105}. Best is trial 2 with value: 0.5698565177771546.
# [I 2025-09-24 06:24:11,702] Trial 8 finished with value: 0.5686751513703292 and parameters: {'learning_rate': 0.013136065501560913, 'num_leaves': 19, 'max_depth': 7, 'min_child_samples': 54, 'subsample': 0.6034356466553568, 'colsample_bytree': 0.8599311702639845, 'reg_alpha': 0.24952257298881275, 'reg_lambda': 0.001604185304480402, 'min_split_gain': 0.9116406097989123}. Best is trial 2 with value: 0.5698565177771546.
# [I 2025-09-24 06:24:28,958] Trial 9 finished with value: 0.5671316357056617 and parameters: {'learning_rate': 0.02104936329068021, 'num_leaves': 106, 'max_depth': 8, 'min_child_samples': 61, 'subsample': 0.9976001419096061, 'colsample_bytree': 0.6108779576713358, 'reg_alpha': 1.2627111969835598e-06, 'reg_lambda': 1.8190477527189177, 'min_split_gain': 0.9215844919927559}. Best is trial 2 with value: 0.5698565177771546.
# [I 2025-09-24 06:24:39,344] Trial 10 finished with value: 0.5692848265981555 and parameters: {'learning_rate': 0.10344507602601231, 'num_leaves': 253, 'max_depth': 3, 'min_child_samples': 37, 'subsample': 0.7708327987197406, 'colsample_bytree': 0.7280070194642475, 'reg_alpha': 0.002226434081673362, 'reg_lambda': 7.925752578609066, 'min_split_gain': 0.6921780074482498}. Best is trial 2 with value: 0.5698565177771546.
# [I 2025-09-24 06:24:49,633] Trial 11 finished with value: 0.5693342776692581 and parameters: {'learning_rate': 0.1100849443199518, 'num_leaves': 256, 'max_depth': 3, 'min_child_samples': 37, 'subsample': 0.7367266835403927, 'colsample_bytree': 0.7481141781098452, 'reg_alpha': 0.0004520080642186843, 'reg_lambda': 9.885013229691987, 'min_split_gain': 0.6738395234493028}. Best is trial 2 with value: 0.5698565177771546.
# [I 2025-09-24 06:25:01,133] Trial 12 finished with value: 0.5595814820356289 and parameters: {'learning_rate': 0.08563449581083148, 'num_leaves': 171, 'max_depth': 7, 'min_child_samples': 40, 'subsample': 0.7088392447941158, 'colsample_bytree': 0.7252004089748916, 'reg_alpha': 7.732082558985796e-05, 'reg_lambda': 0.4306723758228824, 'min_split_gain': 0.7003413378083457}. Best is trial 2 with value: 0.5698565177771546.
# [I 2025-09-24 06:25:13,857] Trial 13 finished with value: 0.569424660708001 and parameters: {'learning_rate': 0.029594170824990614, 'num_leaves': 253, 'max_depth': 3, 'min_child_samples': 20, 'subsample': 0.8235880939758116, 'colsample_bytree': 0.7528286342977242, 'reg_alpha': 0.011585998948861084, 'reg_lambda': 0.1369704700683137, 'min_split_gain': 0.6354426531314035}. Best is trial 2 with value: 0.5698565177771546.
# [I 2025-09-24 06:25:26,938] Trial 14 finished with value: 0.5700820667389911 and parameters: {'learning_rate': 0.027593929201823516, 'num_leaves': 163, 'max_depth': 6, 'min_child_samples': 17, 'subsample': 0.8450156964737695, 'colsample_bytree': 0.6581315100028123, 'reg_alpha': 9.254401150703531, 'reg_lambda': 0.10776289159917608, 'min_split_gain': 0.6212171750703448}. Best is trial 14 with value: 0.5700820667389911.
# [I 2025-09-24 06:25:45,737] Trial 15 finished with value: 0.568643282125581 and parameters: {'learning_rate': 0.023076761932564242, 'num_leaves': 160, 'max_depth': 8, 'min_child_samples': 69, 'subsample': 0.8607175936787527, 'colsample_bytree': 0.6422369031377669, 'reg_alpha': 8.451804769181308, 'reg_lambda': 4.765109234230385e-05, 'min_split_gain': 0.280280051002191}. Best is trial 14 with value: 0.5700820667389911.
# [I 2025-09-24 06:26:01,969] Trial 16 finished with value: 0.5645706874953558 and parameters: {'learning_rate': 0.019768404800017184, 'num_leaves': 146, 'max_depth': 6, 'min_child_samples': 47, 'subsample': 0.6788288583190389, 'colsample_bytree': 0.9774314239952868, 'reg_alpha': 9.222077912763632e-06, 'reg_lambda': 0.675265465088422, 'min_split_gain': 0.7954872263353835}. Best is trial 14 with value: 0.5700820667389911.
# [I 2025-09-24 06:26:19,747] Trial 17 finished with value: 0.55847681828997 and parameters: {'learning_rate': 0.03973778275737697, 'num_leaves': 204, 'max_depth': 9, 'min_child_samples': 21, 'subsample': 0.8438350228991573, 'colsample_bytree': 0.676822506659957, 'reg_alpha': 3.0485817902054464e-08, 'reg_lambda': 0.027719006344778047, 'min_split_gain': 0.5634508260283271}. Best is trial 14 with value: 0.5700820667389911.
# [I 2025-09-24 06:26:34,561] Trial 18 finished with value: 0.561707737634779 and parameters: {'learning_rate': 0.05627629968340515, 'num_leaves': 92, 'max_depth': 12, 'min_child_samples': 11, 'subsample': 0.5147752676871589, 'colsample_bytree': 0.5626028352991437, 'reg_alpha': 0.03884909643121818, 'reg_lambda': 3.9088804291328805e-05, 'min_split_gain': 0.7700523079730247}. Best is trial 14 with value: 0.5700820667389911.
# [I 2025-09-24 06:26:44,410] Trial 19 finished with value: 0.5600300185690001 and parameters: {'learning_rate': 0.29792813561219494, 'num_leaves': 67, 'max_depth': 6, 'min_child_samples': 66, 'subsample': 0.8913640140954195, 'colsample_bytree': 0.7944813503272652, 'reg_alpha': 6.010635588143501, 'reg_lambda': 0.009483465045384784, 'min_split_gain': 0.5361540523622282}. Best is trial 14 with value: 0.5700820667389911.
# [I 2025-09-24 06:27:25,269] Trial 20 finished with value: 0.5520787495843811 and parameters: {'learning_rate': 0.01692607855931988, 'num_leaves': 143, 'max_depth': 6, 'min_child_samples': 51, 'subsample': 0.8035520000249908, 'colsample_bytree': 0.6898549065475484, 'reg_alpha': 3.817937327026825e-05, 'reg_lambda': 0.302666494946733, 'min_split_gain': 0.001951981126511071}. Best is trial 14 with value: 0.5700820667389911.
# [I 2025-09-24 06:27:38,675] Trial 21 finished with value: 0.5662661582708051 and parameters: {'learning_rate': 0.030900629076405835, 'num_leaves': 229, 'max_depth': 4, 'min_child_samples': 25, 'subsample': 0.8190022772210859, 'colsample_bytree': 0.7989051647384257, 'reg_alpha': 0.00681823563514263, 'reg_lambda': 0.12160720858427936, 'min_split_gain': 0.6059459922669933}. Best is trial 14 with value: 0.5700820667389911.
# [I 2025-09-24 06:27:50,927] Trial 22 finished with value: 0.5707336063791232 and parameters: {'learning_rate': 0.02774941045536331, 'num_leaves': 179, 'max_depth': 3, 'min_child_samples': 19, 'subsample': 0.6981997901159129, 'colsample_bytree': 0.7689409063579563, 'reg_alpha': 0.03761758820402238, 'reg_lambda': 2.934645969180967, 'min_split_gain': 0.8297424507603628}. Best is trial 22 with value: 0.5707336063791232.
# [I 2025-09-24 06:28:03,050] Trial 23 finished with value: 0.5709732531215144 and parameters: {'learning_rate': 0.030763105243930885, 'num_leaves': 173, 'max_depth': 4, 'min_child_samples': 28, 'subsample': 0.672305389275794, 'colsample_bytree': 0.9032087189380126, 'reg_alpha': 1.6009009394062108, 'reg_lambda': 2.2901611966692736, 'min_split_gain': 0.8104370714567942}. Best is trial 23 with value: 0.5709732531215144.
# [I 2025-09-24 06:28:15,775] Trial 24 finished with value: 0.5685230715920422 and parameters: {'learning_rate': 0.030623982205120606, 'num_leaves': 180, 'max_depth': 5, 'min_child_samples': 30, 'subsample': 0.652764389736837, 'colsample_bytree': 0.9071971166559182, 'reg_alpha': 1.758197582731716, 'reg_lambda': 1.694209973335528, 'min_split_gain': 0.8210052489332715}. Best is trial 23 with value: 0.5709732531215144.
# [I 2025-09-24 06:28:26,338] Trial 25 finished with value: 0.5694405318608252 and parameters: {'learning_rate': 0.06693166160802934, 'num_leaves': 193, 'max_depth': 3, 'min_child_samples': 10, 'subsample': 0.7321121796208856, 'colsample_bytree': 0.9807166187703873, 'reg_alpha': 0.0713958475745961, 'reg_lambda': 1.8724397349219146, 'min_split_gain': 0.8046169015650549}. Best is trial 23 with value: 0.5709732531215144.
# [I 2025-09-24 06:28:38,750] Trial 26 finished with value: 0.566864333126548 and parameters: {'learning_rate': 0.040931677403104036, 'num_leaves': 224, 'max_depth': 6, 'min_child_samples': 18, 'subsample': 0.5880898102159472, 'colsample_bytree': 0.591326712662253, 'reg_alpha': 1.4236887249078465, 'reg_lambda': 0.0051514430510263285, 'min_split_gain': 0.9978002264325191}. Best is trial 23 with value: 0.5709732531215144.
# [I 2025-09-24 06:28:51,548] Trial 27 finished with value: 0.5703607604832103 and parameters: {'learning_rate': 0.02618074725063293, 'num_leaves': 165, 'max_depth': 4, 'min_child_samples': 31, 'subsample': 0.6990687258408848, 'colsample_bytree': 0.6832306700792121, 'reg_alpha': 0.12946000735435173, 'reg_lambda': 0.6826626833799884, 'min_split_gain': 0.8460160892857367}. Best is trial 23 with value: 0.5709732531215144.
# [I 2025-09-24 06:29:06,827] Trial 28 finished with value: 0.5684660914577969 and parameters: {'learning_rate': 0.01574119876518885, 'num_leaves': 156, 'max_depth': 4, 'min_child_samples': 44, 'subsample': 0.695686161386782, 'colsample_bytree': 0.9241391406628708, 'reg_alpha': 0.06243213942292111, 'reg_lambda': 1.530699975595958, 'min_split_gain': 0.8509304076763208}. Best is trial 23 with value: 0.5709732531215144.
# [I 2025-09-24 06:29:18,550] Trial 29 finished with value: 0.5685553076842997 and parameters: {'learning_rate': 0.04983073698252769, 'num_leaves': 178, 'max_depth': 5, 'min_child_samples': 29, 'subsample': 0.6424304667075625, 'colsample_bytree': 0.5026772564740276, 'reg_alpha': 0.0007617734969112051, 'reg_lambda': 0.001473667927091646, 'min_split_gain': 0.8751482898583941}. Best is trial 23 with value: 0.5709732531215144.
# [I 2025-09-24 06:29:31,251] Trial 30 finished with value: 0.5707265459200815 and parameters: {'learning_rate': 0.025062236250163468, 'num_leaves': 127, 'max_depth': 3, 'min_child_samples': 33, 'subsample': 0.5774350100632576, 'colsample_bytree': 0.6881002725772707, 'reg_alpha': 0.027331927886829026, 'reg_lambda': 5.1464727035266836e-05, 'min_split_gain': 0.7975123870382113}. Best is trial 23 with value: 0.5709732531215144.
# [I 2025-09-24 06:29:43,939] Trial 31 finished with value: 0.5699256349486863 and parameters: {'learning_rate': 0.025660500413327195, 'num_leaves': 127, 'max_depth': 3, 'min_child_samples': 34, 'subsample': 0.6279616437365967, 'colsample_bytree': 0.7060724270824272, 'reg_alpha': 0.016966023984432685, 'reg_lambda': 5.4989490892338915e-05, 'min_split_gain': 0.7523661532626615}. Best is trial 23 with value: 0.5709732531215144.
# [I 2025-09-24 06:29:55,715] Trial 32 finished with value: 0.5696899935258679 and parameters: {'learning_rate': 0.03447959532730912, 'num_leaves': 108, 'max_depth': 4, 'min_child_samples': 99, 'subsample': 0.5612590924334022, 'colsample_bytree': 0.7690988093836967, 'reg_alpha': 0.15997098852704156, 'reg_lambda': 3.581346623774249e-06, 'min_split_gain': 0.8604438987295775}. Best is trial 23 with value: 0.5709732531215144.
# [I 2025-09-24 06:30:09,368] Trial 33 finished with value: 0.5720031333754726 and parameters: {'learning_rate': 0.01735439765184138, 'num_leaves': 128, 'max_depth': 3, 'min_child_samples': 44, 'subsample': 0.6664334699552892, 'colsample_bytree': 0.6647872479493324, 'reg_alpha': 1.5545067555551375, 'reg_lambda': 9.96101959222459e-06, 'min_split_gain': 0.7601243568845031}. Best is trial 33 with value: 0.5720031333754726.
# [I 2025-09-24 06:30:23,706] Trial 34 finished with value: 0.5703233582610612 and parameters: {'learning_rate': 0.016119391983002225, 'num_leaves': 71, 'max_depth': 3, 'min_child_samples': 43, 'subsample': 0.5559966332833179, 'colsample_bytree': 0.8776787524876112, 'reg_alpha': 1.244113760560467, 'reg_lambda': 8.140064950106696e-06, 'min_split_gain': 0.7304202055653428}. Best is trial 33 with value: 0.5720031333754726.
# [I 2025-09-24 06:30:38,951] Trial 35 finished with value: 0.5705540856243134 and parameters: {'learning_rate': 0.017944155530971454, 'num_leaves': 134, 'max_depth': 5, 'min_child_samples': 25, 'subsample': 0.5047381391366471, 'colsample_bytree': 0.5905119473744879, 'reg_alpha': 0.003081468421802556, 'reg_lambda': 6.146737431787948e-07, 'min_split_gain': 0.9792244831010797}. Best is trial 33 with value: 0.5720031333754726.
# [I 2025-09-24 06:30:54,093] Trial 36 finished with value: 0.5665454172847859 and parameters: {'learning_rate': 0.02288784941883601, 'num_leaves': 114, 'max_depth': 3, 'min_child_samples': 24, 'subsample': 0.6638001864249891, 'colsample_bytree': 0.9457782576242882, 'reg_alpha': 0.43265706924344327, 'reg_lambda': 6.901985518262178e-08, 'min_split_gain': 0.4589453825657154}. Best is trial 33 with value: 0.5720031333754726.
# [I 2025-09-24 06:31:13,036] Trial 37 finished with value: 0.5669115428410381 and parameters: {'learning_rate': 0.01456633392500723, 'num_leaves': 92, 'max_depth': 4, 'min_child_samples': 50, 'subsample': 0.6211411254172011, 'colsample_bytree': 0.8225148163423761, 'reg_alpha': 2.145794835282988, 'reg_lambda': 0.00016374463690967052, 'min_split_gain': 0.3707322443691854}. Best is trial 33 with value: 0.5720031333754726.
# [I 2025-09-24 06:31:31,444] Trial 38 finished with value: 0.5703864257941303 and parameters: {'learning_rate': 0.010808577539949231, 'num_leaves': 129, 'max_depth': 4, 'min_child_samples': 35, 'subsample': 0.7211271559807032, 'colsample_bytree': 0.6536483317279654, 'reg_alpha': 0.02572123544774106, 'reg_lambda': 1.203030142694958e-05, 'min_split_gain': 0.7625024493370435}. Best is trial 33 with value: 0.5720031333754726.
# [I 2025-09-24 06:31:43,669] Trial 39 finished with value: 0.5690296477297807 and parameters: {'learning_rate': 0.03513487258371184, 'num_leaves': 145, 'max_depth': 5, 'min_child_samples': 42, 'subsample': 0.577480224752327, 'colsample_bytree': 0.7746626213271635, 'reg_alpha': 0.6272238690468397, 'reg_lambda': 2.003892378851155e-06, 'min_split_gain': 0.8965082868320605}. Best is trial 33 with value: 0.5720031333754726.
# [I 2025-09-24 06:31:57,918] Trial 40 finished with value: 0.5684802486396101 and parameters: {'learning_rate': 0.020329687146310286, 'num_leaves': 187, 'max_depth': 3, 'min_child_samples': 14, 'subsample': 0.767507888002032, 'colsample_bytree': 0.8920924776077161, 'reg_alpha': 0.0015473623113989182, 'reg_lambda': 0.00018431432718187148, 'min_split_gain': 0.649781556583214}. Best is trial 33 with value: 0.5720031333754726.
# [I 2025-09-24 06:32:11,631] Trial 41 finished with value: 0.5706038418175337 and parameters: {'learning_rate': 0.01837327793682219, 'num_leaves': 131, 'max_depth': 4, 'min_child_samples': 26, 'subsample': 0.5034256883181671, 'colsample_bytree': 0.5836257858232323, 'reg_alpha': 0.004773703038504615, 'reg_lambda': 3.918478137992125e-07, 'min_split_gain': 0.9998277851552256}. Best is trial 33 with value: 0.5720031333754726.
# [I 2025-09-24 06:32:27,334] Trial 42 finished with value: 0.5718882212458286 and parameters: {'learning_rate': 0.01290194770265808, 'num_leaves': 96, 'max_depth': 4, 'min_child_samples': 23, 'subsample': 0.5293365879976079, 'colsample_bytree': 0.5296177643574778, 'reg_alpha': 0.24601979648353964, 'reg_lambda': 1.3091130389766523e-07, 'min_split_gain': 0.9463945129667067}. Best is trial 33 with value: 0.5720031333754726.
# [I 2025-09-24 06:32:42,175] Trial 43 finished with value: 0.5720852359479407 and parameters: {'learning_rate': 0.013268869748509802, 'num_leaves': 95, 'max_depth': 3, 'min_child_samples': 32, 'subsample': 0.5335173014819886, 'colsample_bytree': 0.6267739215028296, 'reg_alpha': 0.35453373088191154, 'reg_lambda': 2.8298053829794728e-08, 'min_split_gain': 0.9390075836876688}. Best is trial 43 with value: 0.5720852359479407.
# [I 2025-09-24 06:32:57,647] Trial 44 finished with value: 0.5717760742591946 and parameters: {'learning_rate': 0.013185935527355105, 'num_leaves': 55, 'max_depth': 4, 'min_child_samples': 22, 'subsample': 0.6708671565466402, 'colsample_bytree': 0.6312154814455796, 'reg_alpha': 0.6881505888004295, 'reg_lambda': 1.1481238749641842e-08, 'min_split_gain': 0.9281369881282266}. Best is trial 43 with value: 0.5720852359479407.
# [I 2025-09-24 06:33:15,673] Trial 45 finished with value: 0.5718627408123035 and parameters: {'learning_rate': 0.010243239671500889, 'num_leaves': 41, 'max_depth': 5, 'min_child_samples': 22, 'subsample': 0.5448667440161602, 'colsample_bytree': 0.5406909456875033, 'reg_alpha': 2.7801772197762187, 'reg_lambda': 1.0876285330755244e-08, 'min_split_gain': 0.9343020249323993}. Best is trial 43 with value: 0.5720852359479407.
# [I 2025-09-24 06:33:31,569] Trial 46 finished with value: 0.5717456006068472 and parameters: {'learning_rate': 0.012502461578940584, 'num_leaves': 49, 'max_depth': 5, 'min_child_samples': 39, 'subsample': 0.5315920637268123, 'colsample_bytree': 0.5280728005016424, 'reg_alpha': 3.948156974231359, 'reg_lambda': 1.156798434890592e-08, 'min_split_gain': 0.9351596994438592}. Best is trial 43 with value: 0.5720852359479407.
# [I 2025-09-24 06:33:54,018] Trial 47 finished with value: 0.5692690092854453 and parameters: {'learning_rate': 0.010101718963296426, 'num_leaves': 41, 'max_depth': 7, 'min_child_samples': 22, 'subsample': 0.5354536742414765, 'colsample_bytree': 0.5565134649028018, 'reg_alpha': 0.4912676391797705, 'reg_lambda': 5.790847010655306e-08, 'min_split_gain': 0.9549362654214496}. Best is trial 43 with value: 0.5720852359479407.
# [I 2025-09-24 06:34:10,561] Trial 48 finished with value: 0.5698619330651121 and parameters: {'learning_rate': 0.013639778178027652, 'num_leaves': 56, 'max_depth': 5, 'min_child_samples': 47, 'subsample': 0.6007207931360681, 'colsample_bytree': 0.6196477504498741, 'reg_alpha': 0.26261551218965973, 'reg_lambda': 4.345121761827299e-08, 'min_split_gain': 0.9113640757186875}. Best is trial 43 with value: 0.5720852359479407.
# [I 2025-09-24 06:34:27,487] Trial 49 finished with value: 0.5728629770674987 and parameters: {'learning_rate': 0.011569231480988288, 'num_leaves': 16, 'max_depth': 10, 'min_child_samples': 15, 'subsample': 0.547247457489464, 'colsample_bytree': 0.5507146543429488, 'reg_alpha': 3.6300463205930353, 'reg_lambda': 1.3018760604860127e-07, 'min_split_gain': 0.8935026096031666}. Best is trial 49 with value: 0.5728629770674987.
# Best trial: {'learning_rate': 0.011569231480988288, 'num_leaves': 16, 'max_depth': 10, 'min_child_samples': 15, 'subsample': 0.547247457489464, 'colsample_bytree': 0.5507146543429488, 'reg_alpha': 3.6300463205930353, 'reg_lambda': 1.3018760604860127e-07, 'min_split_gain': 0.8935026096031666}
# Best AUC: 0.5728629770674987

# %%
#Divide the training data into training and validation sets 
#To tune the weights for the weighted average of the models
X_train, X_val, y_train, y_val = train_test_split(X_train_imputed, y, test_size=0.2, random_state=2025, stratify=y)

# %%
# Train final LightGBM model with best hyperparameters
lgb_best_params = study.best_params
lgb_best_params["objective"] = "binary"
lgb_best_params["metric"] = "auc"

train_data = lgb.Dataset(X_train, label=y_train)
data = lgb.Dataset(X_train_imputed, label = y)
lgb_model = lgb.train(
    lgb_best_params,
    train_data,
    num_boost_round=study.best_trial.number
)
val_preds = lgb_model.predict(X_val)
val_auc = roc_auc_score(y_val, val_preds)

print("Validation AUC:", val_auc)
# Out:
# Validation AUC: 0.565508520397956

# %%
# Prepare train, validation and final data for XGBoost
dtrain = xgb.DMatrix(X_train, label=y_train)
dval = xgb.DMatrix(X_val, label=y_val)
ddata = xgb.DMatrix(X_train_imputed, label = y)

# %%
# Train final XGBoost model with best hyperparameters
xgb_model = xgb.train(
    xgb_best_params,
    dtrain,
    num_boost_round=2000,
    evals=[(dval, "validation")],
    early_stopping_rounds=100,
    verbose_eval=False
)

# %%
# Train final CatBoost model with best hyperparameters
cat_model = CatBoostClassifier(**cat_best_params, iterations=2000, task_type="GPU", verbose=0)
cat_model.fit(X_train, y_train)

# %%
# Evaluate CatBoost on validation set
y_pred_cat = cat_model.predict_proba(X_val)[:, 1]

auc_score = roc_auc_score(y_val, y_pred_cat)

print(f'AUC Score: {auc_score}')
# Out:
# AUC Score: 0.5697026316584874

# %%
# Evaluate XGBoost on validation set
y_pred_xgb = xgb_model.predict(dval)

auc_score = roc_auc_score(y_val, y_pred_xgb)

print(f'AUC Score: {auc_score}')
# Out:
# AUC Score: 0.563286965583052

# %%
# Ensemble Predictions of XGBoost and CatBoost with weighted average
weights = [0.7, 0.3]  # [XGB, Cat]
ensemble_proba = weights[0] * y_pred_xgb + weights[1] * y_pred_cat

print("Ensemble AUC:", roc_auc_score(y_val, ensemble_proba))
# Out:
# Ensemble AUC: 0.571816479086296

# %%
# Optimize weights for ensemble of CatBoost, LightGBM, and XGBoost using Optuna

# validation probabilities (already computed earlier)
cat_val_proba = cat_model.predict_proba(X_val)[:, 1]
lgb_val_proba = lgb_model.predict(X_val)
xgb_val_proba = xgb_model.predict(dval)

def objective(trial):
    # suggest weights
    w1 = trial.suggest_float("cat_weight", 0.0, 1.0)
    w2 = trial.suggest_float("lgb_weight", 0.0, 1.0)
    w3 = 1.0 - w1 - w2
    
    if w3 < 0:  # invalid combination
        return 0.0
    
    # weighted ensemble
    ensemble_proba = w1 * cat_val_proba + w2 * lgb_val_proba + w3 * xgb_val_proba
    
    # AUC with probabilities
    auc = roc_auc_score(y_val, ensemble_proba)
    return auc

study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=200)

best_params = study.best_params
best_auc = study.best_value

# final weights
w1 = best_params["cat_weight"]
w2 = best_params["lgb_weight"]
w3 = 1 - w1 - w2

print(f"Best Weights -> CatBoost: {w1:.3f}, LightGBM: {w2:.3f}, XGBoost: {w3:.3f}")
print(f"Best Validation AUC: {best_auc:.4f}")
# Out:
# [I 2025-09-24 06:37:10,391] A new study created in memory with name: no-name-3d50e940-364f-4d2f-ba28-a0a0271557e8
# [I 2025-09-24 06:37:10,393] Trial 0 finished with value: 0.0 and parameters: {'cat_weight': 0.7949002323807223, 'lgb_weight': 0.6691411139789754}. Best is trial 0 with value: 0.0.
# [I 2025-09-24 06:37:10,398] Trial 1 finished with value: 0.5717753391823162 and parameters: {'cat_weight': 0.5112271622876129, 'lgb_weight': 0.08306891303350816}. Best is trial 1 with value: 0.5717753391823162.
# [I 2025-09-24 06:37:10,399] Trial 2 finished with value: 0.0 and parameters: {'cat_weight': 0.8078078549196919, 'lgb_weight': 0.9789012312753728}. Best is trial 1 with value: 0.5717753391823162.
# [I 2025-09-24 06:37:10,404] Trial 3 finished with value: 0.5668100046489291 and parameters: {'cat_weight': 0.05690927864109707, 'lgb_weight': 0.08183172647585901}. Best is trial 1 with value: 0.5717753391823162.
# [I 2025-09-24 06:37:10,405] Trial 4 finished with value: 0.0 and parameters: {'cat_weight': 0.7310651596216771, 'lgb_weight': 0.6380509188266225}. Best is trial 1 with value: 0.5717753391823162.
# [I 2025-09-24 06:37:10,406] Trial 5 finished with value: 0.0 and parameters: {'cat_weight': 0.8790207506975084, 'lgb_weight': 0.14470004945226778}. Best is trial 1 with value: 0.5717753391823162.
# [I 2025-09-24 06:37:10,407] Trial 6 finished with value: 0.0 and parameters: {'cat_weight': 0.82604204287093, 'lgb_weight': 0.6055275463988335}. Best is trial 1 with value: 0.5717753391823162.
# [I 2025-09-24 06:37:10,412] Trial 7 finished with value: 0.5692785188291223 and parameters: {'cat_weight': 0.09787842844660799, 'lgb_weight': 0.25619939613649545}. Best is trial 1 with value: 0.5717753391823162.
# [I 2025-09-24 06:37:10,412] Trial 8 finished with value: 0.0 and parameters: {'cat_weight': 0.9379927192997957, 'lgb_weight': 0.9624130005044915}. Best is trial 1 with value: 0.5717753391823162.
# [I 2025-09-24 06:37:10,413] Trial 9 finished with value: 0.0 and parameters: {'cat_weight': 0.39108498720775764, 'lgb_weight': 0.9240754368209616}. Best is trial 1 with value: 0.5717753391823162.
# [I 2025-09-24 06:37:10,425] Trial 10 finished with value: 0.5714369844618301 and parameters: {'cat_weight': 0.4753783761992871, 'lgb_weight': 0.36503271274010435}. Best is trial 1 with value: 0.5717753391823162.
# [I 2025-09-24 06:37:10,435] Trial 11 finished with value: 0.571547090677146 and parameters: {'cat_weight': 0.4496304260206716, 'lgb_weight': 0.36071555188131305}. Best is trial 1 with value: 0.5717753391823162.
# [I 2025-09-24 06:37:10,446] Trial 12 finished with value: 0.5720238577859487 and parameters: {'cat_weight': 0.3746498282550523, 'lgb_weight': 0.00844689839802408}. Best is trial 12 with value: 0.5720238577859487.
# [I 2025-09-24 06:37:10,457] Trial 13 finished with value: 0.571540613840951 and parameters: {'cat_weight': 0.2642270049924742, 'lgb_weight': 0.01211692244335287}. Best is trial 12 with value: 0.5720238577859487.
# [I 2025-09-24 06:37:10,468] Trial 14 finished with value: 0.5710547311849108 and parameters: {'cat_weight': 0.6202907795713581, 'lgb_weight': 0.207758510672149}. Best is trial 12 with value: 0.5720238577859487.
# [I 2025-09-24 06:37:10,477] Trial 15 finished with value: 0.5720649976899284 and parameters: {'cat_weight': 0.33686012872101306, 'lgb_weight': 0.045906299010030675}. Best is trial 15 with value: 0.5720649976899284.
# [I 2025-09-24 06:37:10,488] Trial 16 finished with value: 0.5721126144301032 and parameters: {'cat_weight': 0.28549615520324556, 'lgb_weight': 0.3542043918680093}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,498] Trial 17 finished with value: 0.5719716832721552 and parameters: {'cat_weight': 0.23370823179259623, 'lgb_weight': 0.44737387317569693}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,508] Trial 18 finished with value: 0.5718266741062326 and parameters: {'cat_weight': 0.22652717670990774, 'lgb_weight': 0.28045233604690695}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,515] Trial 19 finished with value: 0.0 and parameters: {'cat_weight': 0.5968305735877472, 'lgb_weight': 0.7995353383569366}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,525] Trial 20 finished with value: 0.5711149417732426 and parameters: {'cat_weight': 0.1450141695486981, 'lgb_weight': 0.5077662365915119}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,535] Trial 21 finished with value: 0.5720063463399399 and parameters: {'cat_weight': 0.339507812672681, 'lgb_weight': 0.012083159798909178}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,546] Trial 22 finished with value: 0.5720591205607886 and parameters: {'cat_weight': 0.2952983467218039, 'lgb_weight': 0.15146612774866033}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,556] Trial 23 finished with value: 0.564564461551821 and parameters: {'cat_weight': 0.006580492073866628, 'lgb_weight': 0.18075349812532415}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,567] Trial 24 finished with value: 0.5720732736472888 and parameters: {'cat_weight': 0.28287523838626566, 'lgb_weight': 0.3288259882265258}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,577] Trial 25 finished with value: 0.5716132983360288 and parameters: {'cat_weight': 0.1760387810888896, 'lgb_weight': 0.5116553831540882}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,587] Trial 26 finished with value: 0.5711466063057519 and parameters: {'cat_weight': 0.5432319025849524, 'lgb_weight': 0.3429872679260559}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,597] Trial 27 finished with value: 0.5716233734145544 and parameters: {'cat_weight': 0.4084830875789427, 'lgb_weight': 0.4211982820738981}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,608] Trial 28 finished with value: 0.5720762721825643 and parameters: {'cat_weight': 0.33243437990954344, 'lgb_weight': 0.25127446873015946}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,619] Trial 29 finished with value: 0.5711529632005358 and parameters: {'cat_weight': 0.17522581635874313, 'lgb_weight': 0.2864535394408286}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,626] Trial 30 finished with value: 0.0 and parameters: {'cat_weight': 0.6932731461111593, 'lgb_weight': 0.5856216949404907}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,637] Trial 31 finished with value: 0.5720892258549544 and parameters: {'cat_weight': 0.2982381500958118, 'lgb_weight': 0.24880842757872837}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,648] Trial 32 finished with value: 0.5721081765978955 and parameters: {'cat_weight': 0.289905457370499, 'lgb_weight': 0.23523148517625084}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,658] Trial 33 finished with value: 0.5720859874368569 and parameters: {'cat_weight': 0.3321051685563861, 'lgb_weight': 0.23822809898373049}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,669] Trial 34 finished with value: 0.571963767139028 and parameters: {'cat_weight': 0.42268051039201726, 'lgb_weight': 0.12529541276845424}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,680] Trial 35 finished with value: 0.5718858052218653 and parameters: {'cat_weight': 0.20979488579628341, 'lgb_weight': 0.4512782959532985}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,691] Trial 36 finished with value: 0.5692975895134744 and parameters: {'cat_weight': 0.10323753970937233, 'lgb_weight': 0.2176720805469045}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,702] Trial 37 finished with value: 0.5718645755921148 and parameters: {'cat_weight': 0.2772884918802177, 'lgb_weight': 0.10838939037656428}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,714] Trial 38 finished with value: 0.5711274156799886 and parameters: {'cat_weight': 0.5305958705843885, 'lgb_weight': 0.394446361034619}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,725] Trial 39 finished with value: 0.5701109122215979 and parameters: {'cat_weight': 0.11781936049449102, 'lgb_weight': 0.3205430494496169}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,736] Trial 40 finished with value: 0.572068475990848 and parameters: {'cat_weight': 0.3632433915382838, 'lgb_weight': 0.21832768886310347}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,748] Trial 41 finished with value: 0.5717334796298704 and parameters: {'cat_weight': 0.46306529672555286, 'lgb_weight': 0.2499030247796}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,760] Trial 42 finished with value: 0.5721076968322514 and parameters: {'cat_weight': 0.31791982106167604, 'lgb_weight': 0.1710477520360192}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,771] Trial 43 finished with value: 0.5720534833144706 and parameters: {'cat_weight': 0.2969289467302567, 'lgb_weight': 0.14466436613679168}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,783] Trial 44 finished with value: 0.5712671474238264 and parameters: {'cat_weight': 0.2240138929865464, 'lgb_weight': 0.08013895792816061}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,794] Trial 45 finished with value: 0.5677472268346359 and parameters: {'cat_weight': 0.053253411401665285, 'lgb_weight': 0.3038378550609589}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,805] Trial 46 finished with value: 0.5719718032135663 and parameters: {'cat_weight': 0.41038610468716974, 'lgb_weight': 0.1766476009081162}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,816] Trial 47 finished with value: 0.5713186022891538 and parameters: {'cat_weight': 0.4907094589193157, 'lgb_weight': 0.38836647410603814}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,827] Trial 48 finished with value: 0.570614186382236 and parameters: {'cat_weight': 0.17845443046484005, 'lgb_weight': 0.07762135979029197}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,839] Trial 49 finished with value: 0.5720779513623185 and parameters: {'cat_weight': 0.32366832696572106, 'lgb_weight': 0.19349289627809005}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,850] Trial 50 finished with value: 0.571958729599765 and parameters: {'cat_weight': 0.26531885648920384, 'lgb_weight': 0.5541500504738662}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,862] Trial 51 finished with value: 0.5720874267337891 and parameters: {'cat_weight': 0.3179551671613744, 'lgb_weight': 0.2459907628845838}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,873] Trial 52 finished with value: 0.5720034677460754 and parameters: {'cat_weight': 0.3756282134296104, 'lgb_weight': 0.25667265036739295}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,882] Trial 53 finished with value: 0.0 and parameters: {'cat_weight': 0.9940131937572027, 'lgb_weight': 0.6742396411485625}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,893] Trial 54 finished with value: 0.5718639758850597 and parameters: {'cat_weight': 0.24610152227421656, 'lgb_weight': 0.23728763304913822}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,905] Trial 55 finished with value: 0.5720955827497384 and parameters: {'cat_weight': 0.3066847774131676, 'lgb_weight': 0.2961292752127836}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,916] Trial 56 finished with value: 0.57161461769155 and parameters: {'cat_weight': 0.44107370671031765, 'lgb_weight': 0.34534272064077653}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,928] Trial 57 finished with value: 0.5720021483905542 and parameters: {'cat_weight': 0.36975294682187854, 'lgb_weight': 0.29278111665861806}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,939] Trial 58 finished with value: 0.5712816603345597 and parameters: {'cat_weight': 0.2042270076549115, 'lgb_weight': 0.16456050380086953}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,951] Trial 59 finished with value: 0.5720146222973002 and parameters: {'cat_weight': 0.30406803548121975, 'lgb_weight': 0.45440807638858005}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,962] Trial 60 finished with value: 0.5710777599358265 and parameters: {'cat_weight': 0.15432810008146536, 'lgb_weight': 0.38921483560617676}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,973] Trial 61 finished with value: 0.5720480859509747 and parameters: {'cat_weight': 0.33762921497566856, 'lgb_weight': 0.2811819220032674}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,984] Trial 62 finished with value: 0.5718813673896574 and parameters: {'cat_weight': 0.24794194261661764, 'lgb_weight': 0.23524762656465958}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:10,995] Trial 63 finished with value: 0.5720643979828733 and parameters: {'cat_weight': 0.354553864211831, 'lgb_weight': 0.19412932231774604}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:11,006] Trial 64 finished with value: 0.5721123745472811 and parameters: {'cat_weight': 0.31484155432335154, 'lgb_weight': 0.11625749794335033}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:11,018] Trial 65 finished with value: 0.5720566017911571 and parameters: {'cat_weight': 0.39670317289660173, 'lgb_weight': 0.11130615398019741}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:11,028] Trial 66 finished with value: 0.5719135116878108 and parameters: {'cat_weight': 0.3035405979926552, 'lgb_weight': 0.042512136611288054}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:11,039] Trial 67 finished with value: 0.571840947134144 and parameters: {'cat_weight': 0.26874148105674855, 'lgb_weight': 0.13645900495849075}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:11,050] Trial 68 finished with value: 0.5714528167280847 and parameters: {'cat_weight': 0.19781620456414534, 'lgb_weight': 0.2719431717387923}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:11,061] Trial 69 finished with value: 0.5719866759485327 and parameters: {'cat_weight': 0.24413701540153165, 'lgb_weight': 0.3226501324924027}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:11,073] Trial 70 finished with value: 0.5719751615730747 and parameters: {'cat_weight': 0.4352915124575267, 'lgb_weight': 0.05137194182087544}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:11,084] Trial 71 finished with value: 0.5720749528270431 and parameters: {'cat_weight': 0.31366712771607447, 'lgb_weight': 0.20087970649341327}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:11,095] Trial 72 finished with value: 0.5720916246831746 and parameters: {'cat_weight': 0.33433821791052176, 'lgb_weight': 0.16336183471244375}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:11,107] Trial 73 finished with value: 0.5720366915169278 and parameters: {'cat_weight': 0.3893087576644467, 'lgb_weight': 0.1577166028589138}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:11,118] Trial 74 finished with value: 0.5717912913899817 and parameters: {'cat_weight': 0.2676703083566383, 'lgb_weight': 0.1110434663715294}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:11,130] Trial 75 finished with value: 0.5720596003264325 and parameters: {'cat_weight': 0.35006736761679275, 'lgb_weight': 0.22384592421756155}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:11,142] Trial 76 finished with value: 0.5720910249761197 and parameters: {'cat_weight': 0.2940854673076244, 'lgb_weight': 0.3052745093350505}. Best is trial 16 with value: 0.5721126144301032.
# [I 2025-09-24 06:37:11,154] Trial 77 finished with value: 0.5721151331997345 and parameters: {'cat_weight': 0.2881187091142689, 'lgb_weight': 0.36429899133489}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,165] Trial 78 finished with value: 0.5708255231484525 and parameters: {'cat_weight': 0.13739365081803595, 'lgb_weight': 0.42351402943794014}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,176] Trial 79 finished with value: 0.5709694528416759 and parameters: {'cat_weight': 0.5661810748999292, 'lgb_weight': 0.36651941490844075}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,187] Trial 80 finished with value: 0.5719661659672483 and parameters: {'cat_weight': 0.22084095655990282, 'lgb_weight': 0.47104266183017696}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,200] Trial 81 finished with value: 0.5720901853862426 and parameters: {'cat_weight': 0.2755200891396766, 'lgb_weight': 0.3491309638895805}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,211] Trial 82 finished with value: 0.5720761522411533 and parameters: {'cat_weight': 0.28556539670941933, 'lgb_weight': 0.30901535446156686}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,223] Trial 83 finished with value: 0.5714759654204113 and parameters: {'cat_weight': 0.18053530005054189, 'lgb_weight': 0.3714041051856995}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,232] Trial 84 finished with value: 0.0 and parameters: {'cat_weight': 0.8535212308719334, 'lgb_weight': 0.41866530959842047}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,244] Trial 85 finished with value: 0.5719975906169353 and parameters: {'cat_weight': 0.24360959279564515, 'lgb_weight': 0.3395393411447696}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,256] Trial 86 finished with value: 0.572079990366306 and parameters: {'cat_weight': 0.2841702226058691, 'lgb_weight': 0.2700405180200597}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,268] Trial 87 finished with value: 0.5719279046571331 and parameters: {'cat_weight': 0.37825682086642953, 'lgb_weight': 0.35226510713354797}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,276] Trial 88 finished with value: 0.0 and parameters: {'cat_weight': 0.3496399108315609, 'lgb_weight': 0.8702882855192218}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,285] Trial 89 finished with value: 0.0 and parameters: {'cat_weight': 0.7496201034686345, 'lgb_weight': 0.3078624838500226}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,296] Trial 90 finished with value: 0.5717914113313929 and parameters: {'cat_weight': 0.4742834965032122, 'lgb_weight': 0.17045373899919167}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,307] Trial 91 finished with value: 0.572093543745751 and parameters: {'cat_weight': 0.3215215117466888, 'lgb_weight': 0.20856026086273088}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,318] Trial 92 finished with value: 0.5720972619294926 and parameters: {'cat_weight': 0.3205464800246178, 'lgb_weight': 0.2126716569206751}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,330] Trial 93 finished with value: 0.5719256257703238 and parameters: {'cat_weight': 0.4182035267311254, 'lgb_weight': 0.1852379738455642}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,342] Trial 94 finished with value: 0.5720753126512761 and parameters: {'cat_weight': 0.32428449227243794, 'lgb_weight': 0.2091360092216163}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,353] Trial 95 finished with value: 0.5720991809920689 and parameters: {'cat_weight': 0.30230594108414466, 'lgb_weight': 0.14229779657177563}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,365] Trial 96 finished with value: 0.5720645179242844 and parameters: {'cat_weight': 0.3599374355642601, 'lgb_weight': 0.06284883560504151}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,376] Trial 97 finished with value: 0.5716849033584075 and parameters: {'cat_weight': 0.2579227216282468, 'lgb_weight': 0.10584129507579941}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,387] Trial 98 finished with value: 0.5721092560705946 and parameters: {'cat_weight': 0.3267676768397049, 'lgb_weight': 0.13610869631266154}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,399] Trial 99 finished with value: 0.5713846900066256 and parameters: {'cat_weight': 0.22876689802701095, 'lgb_weight': 0.09444150975764179}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,410] Trial 100 finished with value: 0.5720128231761349 and parameters: {'cat_weight': 0.404721193862082, 'lgb_weight': 0.12990828979438057}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,423] Trial 101 finished with value: 0.5721084164807175 and parameters: {'cat_weight': 0.32532676686319073, 'lgb_weight': 0.14391366197528277}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,434] Trial 102 finished with value: 0.5720996607577131 and parameters: {'cat_weight': 0.3088714099171555, 'lgb_weight': 0.1465589302793359}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,445] Trial 103 finished with value: 0.5720972619294927 and parameters: {'cat_weight': 0.30510340773242284, 'lgb_weight': 0.1332114487870639}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,457] Trial 104 finished with value: 0.5708810560217545 and parameters: {'cat_weight': 0.20406426224184002, 'lgb_weight': 0.02822526739886219}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,469] Trial 105 finished with value: 0.5720590006193774 and parameters: {'cat_weight': 0.38101083651608797, 'lgb_weight': 0.134173143690978}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,480] Trial 106 finished with value: 0.5719659260844263 and parameters: {'cat_weight': 0.3035283201420626, 'lgb_weight': 0.0751526847237204}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,492] Trial 107 finished with value: 0.5717826556083884 and parameters: {'cat_weight': 0.25613633506270267, 'lgb_weight': 0.14835044252281182}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,503] Trial 108 finished with value: 0.5720697953463691 and parameters: {'cat_weight': 0.3657627157893811, 'lgb_weight': 0.09371001898914573}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,514] Trial 109 finished with value: 0.572105417945442 and parameters: {'cat_weight': 0.340569574936219, 'lgb_weight': 0.17375444980290805}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,526] Trial 110 finished with value: 0.5720911449175308 and parameters: {'cat_weight': 0.34290725311486125, 'lgb_weight': 0.18094177569602196}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,538] Trial 111 finished with value: 0.5718862849875094 and parameters: {'cat_weight': 0.2802011745485764, 'lgb_weight': 0.1175389354199098}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,550] Trial 112 finished with value: 0.5721068572423742 and parameters: {'cat_weight': 0.3159727455372323, 'lgb_weight': 0.1502478200166648}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,562] Trial 113 finished with value: 0.5720556422598689 and parameters: {'cat_weight': 0.29249219103086715, 'lgb_weight': 0.16064809388520068}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,573] Trial 114 finished with value: 0.5720751927098651 and parameters: {'cat_weight': 0.3383832808609858, 'lgb_weight': 0.14383417549621197}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,584] Trial 115 finished with value: 0.5711565614428663 and parameters: {'cat_weight': 0.22335663421725382, 'lgb_weight': 0.028357549148986805}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,596] Trial 116 finished with value: 0.5716873021866279 and parameters: {'cat_weight': 0.26278777350742216, 'lgb_weight': 0.0895405161768141}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,608] Trial 117 finished with value: 0.5711017482180304 and parameters: {'cat_weight': 0.6559041487085864, 'lgb_weight': 0.12231228001071918}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,619] Trial 118 finished with value: 0.57144286159097 and parameters: {'cat_weight': 0.3930062033715019, 'lgb_weight': 0.5296770553908104}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,631] Trial 119 finished with value: 0.5719791196396384 and parameters: {'cat_weight': 0.308776115112872, 'lgb_weight': 0.06483182206058169}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,640] Trial 120 finished with value: 0.0 and parameters: {'cat_weight': 0.3589647285504162, 'lgb_weight': 0.6819948553001396}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,651] Trial 121 finished with value: 0.5720888660307213 and parameters: {'cat_weight': 0.31444063683725726, 'lgb_weight': 0.22441230624843264}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,663] Trial 122 finished with value: 0.5720618792132419 and parameters: {'cat_weight': 0.3240551949413632, 'lgb_weight': 0.1869909359339527}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,675] Trial 123 finished with value: 0.5719468554000742 and parameters: {'cat_weight': 0.28205115307572837, 'lgb_weight': 0.14568917846783508}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,687] Trial 124 finished with value: 0.5720792707178397 and parameters: {'cat_weight': 0.3308732136330729, 'lgb_weight': 0.17820946459954576}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,699] Trial 125 finished with value: 0.5718312318798513 and parameters: {'cat_weight': 0.25379862153270905, 'lgb_weight': 0.19899548279947876}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,710] Trial 126 finished with value: 0.5718754902605176 and parameters: {'cat_weight': 0.4508264193555891, 'lgb_weight': 0.15955334351422587}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,721] Trial 127 finished with value: 0.5720152220043553 and parameters: {'cat_weight': 0.29675438823741246, 'lgb_weight': 0.12450432908402174}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,733] Trial 128 finished with value: 0.571859777935674 and parameters: {'cat_weight': 0.24045683919152122, 'lgb_weight': 0.2598659252829485}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,745] Trial 129 finished with value: 0.5720633185101741 and parameters: {'cat_weight': 0.34811168885235866, 'lgb_weight': 0.2304856527039408}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,757] Trial 130 finished with value: 0.5719557310644896 and parameters: {'cat_weight': 0.4274295794663673, 'lgb_weight': 0.1000003059610993}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,769] Trial 131 finished with value: 0.5720732736472888 and parameters: {'cat_weight': 0.30917070178728917, 'lgb_weight': 0.21492171027894844}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,780] Trial 132 finished with value: 0.5719642469046721 and parameters: {'cat_weight': 0.27921391001411805, 'lgb_weight': 0.17320101077874187}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,792] Trial 133 finished with value: 0.5719891947181641 and parameters: {'cat_weight': 0.37572838470004366, 'lgb_weight': 0.2891024706206981}. Best is trial 77 with value: 0.5721151331997345.
# [I 2025-09-24 06:37:11,803] Trial 134 finished with value: 0.5721159727896117 and parameters: {'cat_weight': 0.3201677310668995, 'lgb_weight': 0.14401628833846514}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:11,815] Trial 135 finished with value: 0.5721063774767301 and parameters: {'cat_weight': 0.33230902692009967, 'lgb_weight': 0.1416126822257061}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:11,827] Trial 136 finished with value: 0.5720845481399247 and parameters: {'cat_weight': 0.3536649598803415, 'lgb_weight': 0.1371811184882055}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:11,840] Trial 137 finished with value: 0.5717115303516538 and parameters: {'cat_weight': 0.26791204837040494, 'lgb_weight': 0.07692430697010902}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:11,851] Trial 138 finished with value: 0.572086467202501 and parameters: {'cat_weight': 0.33422980186317797, 'lgb_weight': 0.12020849239746813}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:11,862] Trial 139 finished with value: 0.5720661971040386 and parameters: {'cat_weight': 0.2944680597903644, 'lgb_weight': 0.15647131588215799}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:11,874] Trial 140 finished with value: 0.5720602000334877 and parameters: {'cat_weight': 0.3924203852479709, 'lgb_weight': 0.09924578422742786}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:11,885] Trial 141 finished with value: 0.5720693155807252 and parameters: {'cat_weight': 0.32006417071017795, 'lgb_weight': 0.1917392476808314}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:11,896] Trial 142 finished with value: 0.5720951029840944 and parameters: {'cat_weight': 0.31317348209203044, 'lgb_weight': 0.1430883358342354}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:11,908] Trial 143 finished with value: 0.5720829889015813 and parameters: {'cat_weight': 0.33665118803531296, 'lgb_weight': 0.19952009810528462}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:11,920] Trial 144 finished with value: 0.5720616393304199 and parameters: {'cat_weight': 0.36380617237005003, 'lgb_weight': 0.1710516487367421}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:11,931] Trial 145 finished with value: 0.5715485299740783 and parameters: {'cat_weight': 0.23790598225466203, 'lgb_weight': 0.12370639996255182}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:11,943] Trial 146 finished with value: 0.5719742020417866 and parameters: {'cat_weight': 0.28130446761876987, 'lgb_weight': 0.16814060292787636}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:11,954] Trial 147 finished with value: 0.5719259855945568 and parameters: {'cat_weight': 0.303414342412766, 'lgb_weight': 0.059043607962349975}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:11,966] Trial 148 finished with value: 0.5719172298715524 and parameters: {'cat_weight': 0.255112034931039, 'lgb_weight': 0.24114409345485086}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:11,976] Trial 149 finished with value: 0.5720642780414623 and parameters: {'cat_weight': 0.3763404346877566, 'lgb_weight': 0.14504460617878026}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:11,988] Trial 150 finished with value: 0.572093063980107 and parameters: {'cat_weight': 0.33865118808495553, 'lgb_weight': 0.10282122050837417}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:11,999] Trial 151 finished with value: 0.5720973818709036 and parameters: {'cat_weight': 0.29704401121369883, 'lgb_weight': 0.22064619775500696}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,010] Trial 152 finished with value: 0.5721001405233571 and parameters: {'cat_weight': 0.28877825287517583, 'lgb_weight': 0.21436231134261796}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,021] Trial 153 finished with value: 0.5719028369022301 and parameters: {'cat_weight': 0.2675683691194936, 'lgb_weight': 0.1857185959069947}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,032] Trial 154 finished with value: 0.5720639182172294 and parameters: {'cat_weight': 0.2938094115198801, 'lgb_weight': 0.1547939038737986}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,044] Trial 155 finished with value: 0.5720762721825643 and parameters: {'cat_weight': 0.28487571989067695, 'lgb_weight': 0.218574014038106}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,056] Trial 156 finished with value: 0.5719566905957778 and parameters: {'cat_weight': 0.2193871285465505, 'lgb_weight': 0.48847897462637535}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,068] Trial 157 finished with value: 0.57092051674598 and parameters: {'cat_weight': 0.1889928198970009, 'lgb_weight': 0.11884520881752153}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,079] Trial 158 finished with value: 0.5720923443316409 and parameters: {'cat_weight': 0.3175655795995066, 'lgb_weight': 0.25730311601707717}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,091] Trial 159 finished with value: 0.5714655305176528 and parameters: {'cat_weight': 0.3505417769070203, 'lgb_weight': 0.6104627325084155}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,102] Trial 160 finished with value: 0.5718507823298475 and parameters: {'cat_weight': 0.27192854740158523, 'lgb_weight': 0.13488885241210205}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,114] Trial 161 finished with value: 0.5720893457963654 and parameters: {'cat_weight': 0.32303672522228755, 'lgb_weight': 0.2055853605417949}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,126] Trial 162 finished with value: 0.5721102156018828 and parameters: {'cat_weight': 0.3018366139182803, 'lgb_weight': 0.1768623885047429}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,137] Trial 163 finished with value: 0.5721043384727429 and parameters: {'cat_weight': 0.2973089756091969, 'lgb_weight': 0.17392060243592553}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,149] Trial 164 finished with value: 0.572093303862929 and parameters: {'cat_weight': 0.2939923657077274, 'lgb_weight': 0.17471533762048397}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,161] Trial 165 finished with value: 0.571908833972781 and parameters: {'cat_weight': 0.2510679954769085, 'lgb_weight': 0.23746610342356078}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,172] Trial 166 finished with value: 0.5720820293702933 and parameters: {'cat_weight': 0.3384613274421726, 'lgb_weight': 0.19471965002696004}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,184] Trial 167 finished with value: 0.5716028634332702 and parameters: {'cat_weight': 0.23338191341952946, 'lgb_weight': 0.15795657290778375}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,196] Trial 168 finished with value: 0.5719114726838234 and parameters: {'cat_weight': 0.2706309366228766, 'lgb_weight': 0.18015966125613353}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,207] Trial 169 finished with value: 0.5719872756555878 and parameters: {'cat_weight': 0.30481276350572895, 'lgb_weight': 0.08785152877349103}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,219] Trial 170 finished with value: 0.5720604399163097 and parameters: {'cat_weight': 0.36049659323779837, 'lgb_weight': 0.1537041001167267}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,231] Trial 171 finished with value: 0.5720837085500475 and parameters: {'cat_weight': 0.30308353444552827, 'lgb_weight': 0.13338550722384568}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,242] Trial 172 finished with value: 0.5720984613436029 and parameters: {'cat_weight': 0.3250709197452924, 'lgb_weight': 0.11731081965803694}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,254] Trial 173 finished with value: 0.5721034988828657 and parameters: {'cat_weight': 0.32488532281144883, 'lgb_weight': 0.10898544510340091}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,265] Trial 174 finished with value: 0.5720840683742805 and parameters: {'cat_weight': 0.32873489782896675, 'lgb_weight': 0.11329801420367655}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,276] Trial 175 finished with value: 0.5720936636871621 and parameters: {'cat_weight': 0.3494256448726704, 'lgb_weight': 0.08131666856501252}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,288] Trial 176 finished with value: 0.567398677094213 and parameters: {'cat_weight': 0.06735275221727105, 'lgb_weight': 0.1061742629420646}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,300] Trial 177 finished with value: 0.5721098557776497 and parameters: {'cat_weight': 0.3191177572900752, 'lgb_weight': 0.1637117106699103}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,311] Trial 178 finished with value: 0.5719909938393294 and parameters: {'cat_weight': 0.2829809718439187, 'lgb_weight': 0.17070401042332678}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,323] Trial 179 finished with value: 0.5721056578282641 and parameters: {'cat_weight': 0.3166058093892091, 'lgb_weight': 0.14656312940967073}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,334] Trial 180 finished with value: 0.5720468865368644 and parameters: {'cat_weight': 0.3761059165691877, 'lgb_weight': 0.18595215834018902}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,345] Trial 181 finished with value: 0.5720943833356282 and parameters: {'cat_weight': 0.3146122529270489, 'lgb_weight': 0.14670889019726177}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,358] Trial 182 finished with value: 0.5720904252690646 and parameters: {'cat_weight': 0.34187886677337637, 'lgb_weight': 0.15899521669549715}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,370] Trial 183 finished with value: 0.5718001670543973 and parameters: {'cat_weight': 0.2635804603310655, 'lgb_weight': 0.13050568797450338}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,381] Trial 184 finished with value: 0.571988595011109 and parameters: {'cat_weight': 0.28787910682550555, 'lgb_weight': 0.14649476407385117}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,393] Trial 185 finished with value: 0.5720924642730519 and parameters: {'cat_weight': 0.3215250633187885, 'lgb_weight': 0.20086510764719898}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,405] Trial 186 finished with value: 0.5720637982758182 and parameters: {'cat_weight': 0.3623883122378253, 'lgb_weight': 0.17222638290188777}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,417] Trial 187 finished with value: 0.572000589152211 and parameters: {'cat_weight': 0.30440340424180773, 'lgb_weight': 0.0975187415638845}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,429] Trial 188 finished with value: 0.5720958226325604 and parameters: {'cat_weight': 0.33595771423280485, 'lgb_weight': 0.13480148478270698}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,440] Trial 189 finished with value: 0.571988954835342 and parameters: {'cat_weight': 0.4035730109411995, 'lgb_weight': 0.16306176083307916}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,452] Trial 190 finished with value: 0.5719690445611127 and parameters: {'cat_weight': 0.275388311958701, 'lgb_weight': 0.1905685314444361}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,463] Trial 191 finished with value: 0.5720802302491279 and parameters: {'cat_weight': 0.3250071647231913, 'lgb_weight': 0.12022605473827104}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,475] Trial 192 finished with value: 0.5720844281985136 and parameters: {'cat_weight': 0.3100778572498719, 'lgb_weight': 0.11314513255285091}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,486] Trial 193 finished with value: 0.5719491342868834 and parameters: {'cat_weight': 0.3457379464018865, 'lgb_weight': 0.4160222619672789}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,498] Trial 194 finished with value: 0.5718501826227924 and parameters: {'cat_weight': 0.29397177955185755, 'lgb_weight': 0.04234727521327758}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,510] Trial 195 finished with value: 0.5720970220466707 and parameters: {'cat_weight': 0.32664296145063715, 'lgb_weight': 0.14250864455439455}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,521] Trial 196 finished with value: 0.5715942276516767 and parameters: {'cat_weight': 0.25147150846999927, 'lgb_weight': 0.0912182991804723}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,533] Trial 197 finished with value: 0.5719660460258372 and parameters: {'cat_weight': 0.2822775647179863, 'lgb_weight': 0.1624857955839505}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,542] Trial 198 finished with value: 0.0 and parameters: {'cat_weight': 0.3581741852381464, 'lgb_weight': 0.9739682759106274}. Best is trial 134 with value: 0.5721159727896117.
# [I 2025-09-24 06:37:12,555] Trial 199 finished with value: 0.5720116237620247 and parameters: {'cat_weight': 0.31485878505937204, 'lgb_weight': 0.06850274486170604}. Best is trial 134 with value: 0.5721159727896117.
# Best Weights -> CatBoost: 0.320, LightGBM: 0.144, XGBoost: 0.536
# Best Validation AUC: 0.5721

# %%
# Retrain models on full training data with best hyperparameters
xgb_model = xgb.train(
    xgb_best_params,
    ddata,
    num_boost_round=2000,
    evals=[(dval, "validation")],
    early_stopping_rounds=100,
    verbose_eval=False
)
cat_model.fit(X_train_imputed, y)
lgb_model = lgb.train(
    lgb_best_params,
    data,
    num_boost_round=study.best_trial.number
)

# %%
# Final Ensemble Predictions on Test Set
dtest = xgb.DMatrix(X_test_imputed)
test_data = lgb.Dataset(X_test_imputed)
y_test_prob_xgb = xgb_model.predict(dtest)
y_test_prob_cat = cat_model.predict_proba(X_test_imputed)[:, 1]
y_test_prob_lgb= lgb_model.predict(X_test_imputed)
weights = [w1, w2, w3]
en_prob = weights[0]*y_test_prob_cat + weights[1]*y_test_prob_lgb + weights[2]*y_test_prob_xgb

# %%
# Save to CSV
results_df_1 = pd.DataFrame({
    'id' : test_ids,
    'song_popularity': en_prob
})
results_df_1.to_csv('/kaggle/working/predictions_prob_en_3.csv', index=False)

# %%
# Save models using joblib
import joblib

joblib.dump(cat_model, "catboost_model.pkl")
joblib.dump(lgb_model, "lightgbm_model.pkl")
joblib.dump(xgb_model, "xgboost_model.pkl")

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from lightgbm import LGBMClassifier

X_adv = pd.concat([X_train, X_val])
y_adv = np.concatenate([np.zeros(len(X_train)), np.ones(len(X_val))])
Xtr, Xva, ytr, yva = train_test_split(X_adv, y_adv, test_size=0.2, stratify=y_adv, random_state=42)
m = LGBMClassifier(n_estimators=200).fit(Xtr, ytr)
print("Adversarial AUC:", roc_auc_score(yva, m.predict_proba(Xva)[:,1]))

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import QuantileTransformer

def transform_features(df, skew_threshold=1.0, use_quantile=False):
    df_transformed = df.copy()
    
    numeric_cols = df_transformed.select_dtypes(include=[np.number]).columns
    
    # 1. Apply log1p for skewed features
    for col in numeric_cols:
        skew_val = df_transformed[col].skew()
        if abs(skew_val) > skew_threshold:
            df_transformed[col] = np.log1p(df_transformed[col].clip(lower=0))  # clip negatives
            print(f"Applied log1p to: {col} (skew={skew_val:.2f})")
    
    # 2. Optionally apply quantile transformation
    # if use_quantile:
    #     qt = QuantileTransformer(output_distribution="normal", random_state=42)
    #     df_transformed[numeric_cols] = qt.fit_transform(df_transformed[numeric_cols])
    #     print("Applied QuantileTransformer to numeric features")
    
    return df_transformed

# %%
X_train_transformed = transform_features(X_train, skew_threshold=1.0, use_quantile=False)
X_val_transformed   = transform_features(X_val, skew_threshold=1.0, use_quantile=False)

# %%
dtrain_trans = xgb.DMatrix(X_train_transformed, label = y_train)
dval_trans = xgb.DMatrix(X_val_transformed, label = y_val)

xgb_model = xgb.train(
    xgb_best_params,
    dtrain_trans,
    num_boost_round=2000,
    evals=[(dval, "validation")],
    early_stopping_rounds=100,
    verbose_eval=False
)

# %%
cat_model = CatBoostClassifier(**cat_best_params, iterations=2000, task_type="GPU", verbose=0)
cat_model.fit(X_train, y_train)

# %%
y_pred_cat = cat_model.predict_proba(X_val_transformed)[:, 1]
# y_pred = (y_pred_proba > 0.35).astype(int)

auc_score = roc_auc_score(y_val, y_pred_cat)

print(f'AUC Score: {auc_score}')

# %%
y_pred_xgb = xgb_model.predict(dval_trans)
# y_pred = (y_pred_proba > 0.35).astype(int)

auc_score = roc_auc_score(y_val, y_pred_xgb)

print(f'AUC Score: {auc_score}')

# %%
weights = [0.7, 0.3]  # [XGB, Cat]
ensemble_proba = weights[0] * y_pred_xgb + weights[1] * y_pred_cat


print("Ensemble AUC:", roc_auc_score(y_val, ensemble_proba))

# %%
# best_params = {'learning_rate': 0.16480795387917288, 'depth': 5, 'l2_leaf_reg': 0.0005322391948166793, 'random_strength': 7.786614741276959, 'bootstrap_type': 'Bernoulli', 'subsample': 0.5875758867895423}

# %%
# Optuna Objective Function for XGBoost with transformed features
def objective(trial):
    # Define hyperparameter search space
    params = {
        "objective": "binary:logistic",
        "eval_metric": "auc",
        "tree_method": "hist", 
        "device": "cuda",      
        "eta": trial.suggest_float("eta", 0.01, 0.3),
        "max_depth": trial.suggest_int("max_depth", 3, 12),
        "subsample": trial.suggest_float("subsample", 0.5, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1.0),
        "gamma": trial.suggest_float("gamma", 0.0, 5.0),
        "lambda": trial.suggest_float("lambda", 1e-8, 10.0, log=True),
        "alpha": trial.suggest_float("alpha", 1e-8, 10.0, log=True),
    }

    # Stratified k-fold CV
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    aucs = []

    for train_idx, val_idx in skf.split(X_train, y_train):
        X_tr, X_val = X_train.iloc[train_idx], X_train.iloc[val_idx]
        y_tr, y_val = y_train.iloc[train_idx], y_train.iloc[val_idx]

        dtrain = xgb.DMatrix(X_tr, label=y_tr)
        dval = xgb.DMatrix(X_val, label=y_val)

        model = xgb.train(
            params,
            dtrain,
            num_boost_round=1000,
            evals=[(dval, "validation")],
            early_stopping_rounds=50,
            verbose_eval=False
        )

        preds_prob = model.predict(dval)
        preds = (preds_prob > 0.35).astype(int)
        aucs.append(roc_auc_score(y_val, preds))

    return np.mean(aucs)


# Run Optuna
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=50) 

print("Best params:", study.best_trial.params)
print("Best AUC:", study.best_trial.value)

# %%
xgb_best_params = {'eta': 0.01109609133854797, 'max_depth': 3, 'subsample': 0.8281878643153439, 'colsample_bytree': 0.9931500979412877, 'gamma': 0.06097481929038295, 'lambda': 1.3089984380695487, 'alpha': 0.010773357859785837, 'seed': 42}
dtrain = xgb.DMatrix(X_train, label=y_train)
dval = xgb.DMatrix(X_val, label=y_val)

# %%
# Train final XGBoost model with best hyperparameters
xgb_model = xgb.train(
    xgb_best_params,
    dtrain,
    num_boost_round=150,
    evals=[(dval, "validation")],
    verbose_eval=False
)

# %%
# Define XGBoost Classifier model
model = xgb.XGBClassifier(
    objective='binary:logistic',
    n_estimators=150,
    learning_rate=0.179,
    max_depth=11,
    subsample=0.7,
    colsample_bytree=0.7,
    gamma= 0.21,
    reg_lambda= 2.35e-08,
    alpha= 2.05e-06,
    eval_metric='auc',
    tree_method='hist',
    device='cuda'
)

# %%
# Train XGBoost Classifier on train set and evaluate on validation set
model.fit(X_train, y_train)

y_prob = model.predict_proba(X_val)[:,1]
y_pred = (y_prob > 0.35).astype(int)
auc_score = roc_auc_score(y_val, y_pred)

print(f'AUC Score: {auc_score}')

# %%
# import numpy as np
# import pandas as pd
# import os
# import xgboost as xgb
# from sklearn.model_selection import KFold
# from sklearn.metrics import roc_auc_score

# Install Optuna
# !pip install optuna

# import optuna

# --- Data Loading ---
# train_df = pd.read_csv('/kaggle/input/iisc-umc-301-kaggle-competition-1/train.csv')
# X = train_df.drop(['id', 'song_popularity'], axis=1)
# y = train_df['song_popularity']

# --- Define the Optuna Objective Function ---
# def objective(trial):
#     # Suggest hyperparameters to the trial
#     param = {
#         'objective': 'binary:logistic',
#         'eval_metric': 'auc',
#         'tree_method': 'hist',
#         'device':'cuda',
        
#         'n_estimators': trial.suggest_int('n_estimators', 100, 500),
#         'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True),
#         'max_depth': trial.suggest_int('max_depth', 3, 15),
#         'subsample': trial.suggest_float('subsample', 0.6, 1.0),
#         'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
#         'gamma': trial.suggest_float('gamma', 0.0, 1.0),
#         'lambda': trial.suggest_float('lambda', 1e-8, 1.0, log=True),
#         'alpha': trial.suggest_float('alpha', 1e-8, 1.0, log=True),
#     }

#     # Set up K-fold cross-validation
#     kf = KFold(n_splits=5, shuffle=True, random_state=42)
#     auc_scores = []
    
#     # Loop through each fold
#     for train_index, val_index in kf.split(X, y):
#         X_train, X_val = X.iloc[train_index], X.iloc[val_index]
#         y_train, y_val = y.iloc[train_index], y.iloc[val_index]

#         # Initialize and fit the model with the current trial's parameters
#         model = xgb.XGBClassifier(**param, early_stopping_rounds=50,)
#         model.fit(X_train, y_train, 
#                   eval_set=[(X_val, y_val)], 
#                   verbose=False
#                 )
        
#         # Predict probabilities and calculate AUC
#         y_pred_proba = model.predict(X_val)
#         fold_auc = roc_auc_score(y_val, y_pred_proba)
#         auc_scores.append(fold_auc)

#     # Return the average AUC score across all folds
#     return np.mean(auc_scores)

# # --- Run the Optuna Study ---
# # Create a study object and specify that we want to maximize the AUC score
# study = optuna.create_study(direction='maximize')
# # Run the optimization for a specified number of trials
# study.optimize(objective, n_trials=200)

# # --- Print the results ---
# print("\n--- Optuna Optimization Results ---")
# print(f"Best AUC score: {study.best_value:.4f}")
# print("Best hyperparameters found:")
# for key, value in study.best_params.items():
#     print(f"  {key}: {value}")

# %%
# Define the XGBoost Classifier with the best hyperparameters found by Optuna
new_model = xgb.XGBClassifier(
        objective='binary:logistic',
        n_estimators= 223,
        learning_rate= 0.19146753175063527,
        max_depth= 14,
        subsample= 0.6004353115430108,
        colsample_bytree= 0.9343428565854878,
        gamma= 0.2092019760043383,
        reg_lambda= 2.349046247166798e-08,
        alpha= 2.048689819651056e-06,
        eval_metric='auc',
        tree_method='hist',
        device = 'cuda'
)

# %%
# Train the new model on the entire training set and evaluate on validation set
new_model.fit(X_train, y_train)
y_pred_proba_new = new_model.predict_proba(X_val)[:, 1]

auc_score = roc_auc_score(y_val, y_pred_proba_new)

print(f'AUC Score: {auc_score}')

# %%
# Make predictions on the test set using the new model
y_test_2 = new_model.predict(X_test)

results_df_1 = pd.DataFrame({
    'id' : test_ids,
    'song_popularity': y_test_2
})
results_df_1.to_csv('/kaggle/working/predictions_7.csv', index=False)

# %%
# Try using RandomForestClassifier for classification
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=42)
auc_scores = []

# %%
# Optuna Objective Function for RandomForest with KNN Imputer

# def objective(trial):
#     n_neighbors = trial.suggest_int('imputer__n_neighbors', 2, 10)
#     n_estimators = trial.suggest_int('classifier__n_estimators', 50, 500)
#     max_depth = trial.suggest_int('classifier__max_depth', 2, 32)
#     min_samples_split = trial.suggest_int('classifier__min_samples_split', 2, 20)
#     min_samples_leaf = trial.suggest_int('classifier__min_samples_leaf', 1, 20)
#     max_features = trial.suggest_categorical('classifier__max_features', ['sqrt', 'log2', None])

#     pipeline = Pipeline([
#         ('imputer', KNNImputer()),
#         ('classifier', RandomForestClassifier(random_state=42))
#     ])
    
#     params = {
#         'imputer__n_neighbors': n_neighbors,
#         'classifier__n_estimators': n_estimators,
#         'classifier__max_depth': max_depth,
#         'classifier__min_samples_split': min_samples_split,
#         'classifier__min_samples_leaf': min_samples_leaf,
#         'classifier__max_features': max_features
#     }
#     pipeline.set_params(**params)
    
#     pipeline.fit(X_train, y_train)

#     y_pred_proba = pipeline.predict(X_val)
#     auc_score = roc_auc_score(y_val, y_pred_proba)

#     return auc_score

# study = optuna.create_study(direction='maximize')
# study.optimize(objective, n_trials=100)

# print("Best hyperparameters:", study.best_params)
# print("Best AUC Score:", study.best_value)

# best_params = study.best_params
# best_model = RandomForestClassifier(random_state=42)
# best_model.set_params(**{k.replace('classifier__', ''): v for k, v in best_params.items() if k.startswith('classifier__')})

# best_imputer = KNNImputer()
# best_imputer.set_params(**{k.replace('imputer__', ''): v for k, v in best_params.items() if k.startswith('imputer__')})

# final_pipeline = Pipeline([
#     ('imputer', best_imputer),
#     ('classifier', best_model)
# ])

# final_pipeline.fit(X_train, y_train)

# y_pred_proba = final_pipeline.predict(X_val)
# final_auc = roc_auc_score(y_val, y_pred_proba)
# print(f"AUC score of the final model on validation set: {final_auc}")

# %%
# Manual K-Fold Cross-Validation with RandomForest and KNN Imputer

# for fold, (train_index, val_index) in enumerate(kf.split(X, y)):
#     print(f"--- Fold {fold+1}/5 ---")
    
#     X_train, X_val = X.iloc[train_index], X.iloc[val_index]
#     y_train, y_val = y.iloc[train_index], y.iloc[val_index]

#     imputer = KNNImputer(n_neighbors=5)
#     imputer.fit(X_train)
#     X_train_imputed = imputer.transform(X_train)
#     X_val_imputed = imputer.transform(X_val)
    
#     scaler = StandardScaler()
#     scaler.fit(X_train_imputed)
#     X_train_scaled = scaler.transform(X_train_imputed)
#     X_val_scaled = scaler.transform(X_val_imputed)
    
#     model = RandomForestClassifier(
#         n_estimators=200, 
#         max_depth=10, 
#         random_state=42, 
#         n_jobs=-1
#     )
    
#     model.fit(X_train_scaled, y_train)
    
#     y_pred_proba = model.predict(X_val_scaled)
    
#     fold_auc = roc_auc_score(y_val, y_pred_proba)
#     auc_scores.append(fold_auc)
#     print(f"Fold {fold+1} AUC: {fold_auc:.4f}")

# print("\n--- Cross-Validation Results ---")
# print(f"Average AUC: {np.mean(auc_scores):.4f}")
# print(f"Standard Deviation: {np.std(auc_scores):.4f}")

# %%
# Try using CatBoostClassifier for classification
from catboost import CatBoostClassifier, Pool
from sklearn.model_selection import StratifiedKFold

# %%
# Optuna Objective Function for CatBoost with pruning

def objective(trial):
    params = {
        'iterations': trial.suggest_int('iterations', 100, 1000),
        'learning_rate': trial.suggest_float('learning_rate', 0.05, 0.3, log=True),
        'depth': trial.suggest_int('depth', 4, 10),
        'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 1e-8, 10.0, log=True),
        'bootstrap_type': trial.suggest_categorical('bootstrap_type', ['Bayesian', 'Bernoulli']),
        'eval_metric': 'AUC',
        'early_stopping_rounds': 1000,
        'verbose': 0,
        'random_seed': 42
    }
    
    model = CatBoostClassifier(**params)
    
    pruning_callback = optuna.integration.CatBoostPruningCallback(trial, 'AUC')
    
    train_pool = Pool(X_train, y_train)
    val_pool = Pool(X_val, y_val)
    
    model.fit(train_pool, eval_set=val_pool, callbacks=[pruning_callback])
    
    preds_proba = model.predict(X_val)
    
    auc_score = roc_auc_score(y_val, preds_proba)
    return auc_score

study = optuna.create_study(direction='maximize', pruner=optuna.pruners.MedianPruner(n_startup_trials=5, n_warmup_steps=30))
study.optimize(objective, n_trials=100)

# %%
# print("Best trial:")
# trial = study.best_trial
# print(f"  Value: {trial.value}")
# print("  Params:")
# for key, value in trial.params.items():
#     print(f"    {key}: {value}")

# %%
# Train final CatBoost model with best hyperparameters

cat_model = CatBoostClassifier(
    verbose=0,
    random_state=42,
    iterations = 520,
    learning_rate = 0.17,
    depth = 9,
    l2_leaf_reg = 5.79e-07,
    bootstrap_type = 'Bayesian',
    task_type='GPU'
)
cat_model.fit(X_train, y_train)

# Make predictions

# %%
# Evaluate CatBoost on validation set
y_pred_cat_prob = cat_model.predict_proba(X_val)[:, 1]
y_pred_cat = (y_pred_cat_prob > 0.5).astype(int)
cat_auc = roc_auc_score(y_val, y_pred_cat_prob)
print("CatBoost AUC: ",cat_auc)

# %%
# Make predictions on the test set

y_test_cat_proba = cat_model.predict_proba(X_test)[:, 1]
y_test_cat = (y_test_cat_proba > 0.35).astype(int)

results_df_cat = pd.DataFrame({
    'id' : test_ids,
    'song_popularity': y_test_cat
})
results_df_cat.to_csv('/kaggle/working/predictions_cat_3.csv', index=False)

# %%
# Feature Importance from CatBoost and XGBoost

feature_importance_cat = cat_model.get_feature_importance()
feature_importance_xgb = model.feature_importances_
feature_names = X_train.columns 


importance_df_cat = pd.DataFrame({
    'feature': feature_names,
    'importance': feature_importance_cat
}).sort_values(by='importance', ascending=False)

importance_df = pd.DataFrame({
    'feature': feature_names,
    'importance': feature_importance_xgb
}).sort_values(by='importance', ascending=False)

print(importance_df)
print(importance_df_cat)

# %%
# Make predictions on the test set using XGBoost and CatBoost and ensemble them

y_test_en_prob = (y_test_cat_proba + y_test_1_proba)/2

# results_df_en = pd.DataFrame({
#     'id' : test_ids,
#     'song_popularity': y_test_en
# })
# results_df_1.to_csv('/kaggle/working/predictions_en.csv', index=False)

# %%
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score
import xgboost as xgb
from catboost import CatBoostClassifier

# Using Stratified K-Fold Cross-Validation to evaluate XGBoost and CatBoost

# Define models (reuse your tuned params)
xgb_model = xgb.XGBClassifier(
    objective='binary:logistic',
    n_estimators=150,
    learning_rate=0.179,
    max_depth=11,
    subsample=0.7,
    colsample_bytree=0.7,
    gamma=0.21,
    reg_lambda=2.35e-08,
    alpha=2.05e-06,
    eval_metric='auc',
    tree_method='hist',
    device='cuda',
    random_state=42,
    use_label_encoder=False
)

cat_model = CatBoostClassifier(
    verbose=0,
    random_state=42,
    iterations = 520,
    learning_rate = 0.17,
    depth = 9,
    l2_leaf_reg = 5.79e-07,
    bootstrap_type = 'Bayesian',
    task_type='GPU'
)

# Stratified KFold
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

xgb_scores = []
cat_scores = []

for train_idx, val_idx in skf.split(X, y):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]
    
    # XGBoost
    xgb_model.fit(X_train, y_train)
    xgb_pred_proba = xgb_model.predict_proba(X_val)[:, 1]
    xgb_pred = (xgb_pred_proba > 0.35).astype(int)
    xgb_auc = roc_auc_score(y_val, xgb_pred)
    xgb_scores.append(xgb_auc)
    
    # CatBoost
    cat_model.fit(X_train, y_train)
    cat_pred_proba = cat_model.predict_proba(X_val)[:, 1]
    cat_pred = (cat_pred_proba > 0.35).astype(int)
    cat_auc = roc_auc_score(y_val, cat_pred)
    cat_scores.append(cat_auc)

print(f"XGBoost CV AUC: {np.mean(xgb_scores):.4f} ± {np.std(xgb_scores):.4f}")
print(f"CatBoost CV AUC: {np.mean(cat_scores):.4f} ± {np.std(cat_scores):.4f}")

# %%
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score
import xgboost as xgb
from catboost import CatBoostClassifier

# Using Stratified K-Fold Cross-Validation with imbalance handling

# Compute imbalance ratio
pos = y.sum()
neg = len(y) - pos
scale_pos_weight = neg / pos
print(f"scale_pos_weight (neg/pos): {scale_pos_weight:.2f}")

# Define models with imbalance handling
xgb_model = xgb.XGBClassifier(
    objective='binary:logistic',
    n_estimators=150,
    learning_rate=0.179,
    max_depth=11,
    subsample=0.7,
    colsample_bytree=0.7,
    gamma=0.21,
    reg_lambda=2.35e-08,
    alpha=2.05e-06,
    eval_metric='auc',
    tree_method='hist',
    device='cuda',
    random_state=42,
    use_label_encoder=False,
    scale_pos_weight=scale_pos_weight
)

cat_model = CatBoostClassifier(
    verbose=0,
    random_state=42,
    iterations=520,
    learning_rate=0.17,
    depth=9,
    l2_leaf_reg=5.79e-07,
    bootstrap_type='Bayesian',
    task_type='GPU',
    class_weights=[1.0, scale_pos_weight]  # weight negative=1, positive=ratio
)

# Stratified KFold
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

xgb_scores = []
cat_scores = []

for train_idx, val_idx in skf.split(X, y):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]
    
    # XGBoost
    xgb_model.fit(X_train, y_train)
    xgb_pred_proba = xgb_model.predict_proba(X_val)[:, 1]
    xgb_pred = (xgb_pred_proba > 0.5).astype(int)
    xgb_auc = roc_auc_score(y_val, xgb_pred)
    xgb_scores.append(xgb_auc)
    
    # CatBoost
    cat_model.fit(X_train, y_train)
    cat_pred_proba = cat_model.predict_proba(X_val)[:, 1]
    cat_pred = (cat_pred_proba > 0.5).astype(int)
    cat_auc = roc_auc_score(y_val, cat_pred)
    cat_scores.append(cat_auc)

print(f"XGBoost (weighted) CV AUC: {np.mean(xgb_scores):.4f} ± {np.std(xgb_scores):.4f}")
print(f"CatBoost (weighted) CV AUC: {np.mean(cat_scores):.4f} ± {np.std(cat_scores):.4f}")

# %%
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score
import xgboost as xgb
from catboost import CatBoostClassifier

# Using Stratified K-Fold Cross-Validation with imbalance handling and ensembling

# imbalance ratio
pos = y.sum()
neg = len(y) - pos
scale_pos_weight = neg / pos
print(f"scale_pos_weight (neg/pos): {scale_pos_weight:.2f}")

# Define models
xgb_model = xgb.XGBClassifier(
    objective='binary:logistic',
    n_estimators=150,
    learning_rate=0.179,
    max_depth=11,
    subsample=0.7,
    colsample_bytree=0.7,
    gamma=0.21,
    reg_lambda=2.35e-08,
    alpha=2.05e-06,
    eval_metric='auc',
    tree_method='hist',
    device='cuda',
    random_state=42,
    use_label_encoder=False
)

cat_model = CatBoostClassifier(
    verbose=0,
    random_state=42,
    iterations=520,
    learning_rate=0.17,
    depth=9,
    l2_leaf_reg=5.79e-07,
    bootstrap_type='Bayesian',
    task_type='GPU',
    class_weights=[1.0, scale_pos_weight]
)

# Stratified KFold
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

xgb_scores = []
cat_scores = []
ensemble_scores = []

# ensemble weights (you can tune these!)
cat_weight = 0.7
xgb_weight = 0.3

for train_idx, val_idx in skf.split(X, y):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]
    
    # XGBoost
    xgb_model.fit(X_train, y_train)
    xgb_pred_proba = xgb_model.predict_proba(X_val)[:, 1]
    xgb_pred = (xgb_pred_proba > 0.5).astype(int)
    xgb_auc = roc_auc_score(y_val, xgb_pred)
    xgb_scores.append(xgb_auc)
    
    # CatBoost
    cat_model.fit(X_train, y_train)
    cat_pred_proba = cat_model.predict_proba(X_val)[:, 1]
    cat_pred = (cat_pred_proba > 0.5).astype(int)
    cat_auc = roc_auc_score(y_val, cat_pred)
    cat_scores.append(cat_auc)
    
    # Weighted Ensemble
    ensemble_pred = xgb_weight * xgb_pred + cat_weight * cat_pred
    ensemble_auc = roc_auc_score(y_val, ensemble_pred)
    ensemble_scores.append(ensemble_auc)

print(f"XGBoost CV AUC: {np.mean(xgb_scores):.4f} ± {np.std(xgb_scores):.4f}")
print(f"CatBoost CV AUC: {np.mean(cat_scores):.4f} ± {np.std(cat_scores):.4f}")
print(f"Ensemble ({xgb_weight:.1f}*XGB + {cat_weight:.1f}*Cat) CV AUC: "
      f"{np.mean(ensemble_scores):.4f} ± {np.std(ensemble_scores):.4f}")

# %%
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score
import xgboost as xgb
from catboost import CatBoostClassifier

# Using Stratified K-Fold Cross-Validation with imbalance handling and ensembling with different weights

# imbalance ratio
pos = y.sum()
neg = len(y) - pos
scale_pos_weight = neg / pos
print(f"scale_pos_weight (neg/pos): {scale_pos_weight:.2f}")

# Define models
xgb_model = xgb.XGBClassifier(
    objective='binary:logistic',
    n_estimators=150,
    learning_rate=0.179,
    max_depth=11,
    subsample=0.7,
    colsample_bytree=0.7,
    gamma=0.21,
    reg_lambda=2.35e-08,
    alpha=2.05e-06,
    eval_metric='auc',
    tree_method='hist',
    device='cuda',
    random_state=42,
    use_label_encoder=False
)

cat_model = CatBoostClassifier(
    verbose=0,
    random_state=42,
    iterations=520,
    learning_rate=0.17,
    depth=9,
    l2_leaf_reg=5.79e-07,
    bootstrap_type='Bayesian',
    task_type='GPU',
    class_weights=[1.0, scale_pos_weight]
)

# Stratified KFold
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# weight search
weight_grid = np.linspace(0, 1, 11)  # 0.0, 0.1, ... 1.0
results = {}

for w in weight_grid:
    ensemble_scores = []
    for train_idx, val_idx in skf.split(X, y):
        X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
        y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]

        # Fit models
        xgb_model.fit(X_train, y_train)
        xgb_pred_proba = xgb_model.predict_proba(X_val)[:, 1]
        xgb_pred = (xgb_pred_proba > 0.5).astype(int)

        cat_model.fit(X_train, y_train)
        cat_pred = cat_model.predict_proba(X_val)[:, 1]

        # Ensemble with current weight
        ensemble_pred = w * xgb_pred + (1 - w) * cat_pred
        ensemble_auc = roc_auc_score(y_val, ensemble_pred)
        ensemble_scores.append(ensemble_auc)

    results[w] = (np.mean(ensemble_scores), np.std(ensemble_scores))

# Display results sorted by AUC
for w, (mean_auc, std_auc) in sorted(results.items(), key=lambda x: -x[1][0]):
    print(f"Weight {w:.1f} (XGB {w:.1f}, Cat {1-w:.1f}) "
          f"=> CV AUC: {mean_auc:.4f} ± {std_auc:.4f}")

# %%
# Predict on test set with best ensemble weights
y_test_cat_proba = cat_model.predict_proba(X_test)[:, 1]
y_test_cat = (y_test_cat_proba > 0.5).astype(int)

results_df_cat = pd.DataFrame({
    'id' : test_ids,
    'song_popularity': y_test_cat
})
results_df_cat.to_csv('/kaggle/working/predictions_cat_5.csv', index=False)

# %%
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score
from catboost import CatBoostClassifier

# Using Stratified K-Fold Cross-Validation with CatBoost, imbalance handling, and bagging

# imbalance ratio
pos = y.sum()
neg = len(y) - pos
scale_pos_weight = neg / pos
print(f"scale_pos_weight (neg/pos): {scale_pos_weight:.2f}")

# Bagging settings
n_bags = 5
seeds = [42, 99, 123, 2024, 2025]  # you can expand this list

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

bagged_scores = []

for train_idx, val_idx in skf.split(X, y):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]

    bagged_preds_proba = np.zeros(len(X_val))

    for seed in seeds[:n_bags]:
        cat_model = CatBoostClassifier(
            verbose=0,
            random_state=seed,
            iterations=520,
            learning_rate=0.17,
            depth=9,
            l2_leaf_reg=5.79e-07,
            bootstrap_type='Bayesian',
            task_type='GPU',
            class_weights=[1.0, scale_pos_weight]
        )

        cat_model.fit(X_train, y_train)
        bagged_preds_proba += cat_model.predict_proba(X_val)[:, 1]

    # Average predictions from all bags
    bagged_preds_proba /= n_bags
    

    # Get hard labels if needed
    bagged_preds = (bagged_preds_proba > 0.5).astype(int)
    bagged_auc = roc_auc_score(y_val, bagged_preds)
    bagged_scores.append(bagged_auc)

print(f"Bagged CatBoost (n={n_bags}) CV AUC: {np.mean(bagged_scores):.4f} ± {np.std(bagged_scores):.4f}")

# %%
import optuna
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score
from catboost import CatBoostClassifier

# Optuna Objective Function for CatBoost with more hyperparameters

def objective(trial):
    params = {
        "iterations": 5000,  # we’ll use early stopping anyway
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3),
        "depth": trial.suggest_int("depth", 4, 12),
        "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1e-8, 10.0, log=True),
        "random_strength": trial.suggest_float("random_strength", 0.1, 10.0),
        "task_type": "GPU", 
        "loss_function": "Logloss",
        "eval_metric": "AUC",
        "verbose": 0,
        "random_seed": 42
    }

    # Choose bootstrap type
    bootstrap_type = trial.suggest_categorical("bootstrap_type", ["Bayesian", "Bernoulli", "Poisson"])
    params["bootstrap_type"] = bootstrap_type

    if bootstrap_type == "Bayesian":
        params["bagging_temperature"] = trial.suggest_float("bagging_temperature", 0, 10)
    else:
        params["subsample"] = trial.suggest_float("subsample", 0.5, 1.0)

    # Cross-validation
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    aucs = []

    for train_idx, val_idx in skf.split(X_train, y_train):
        X_tr, X_val = X_train.iloc[train_idx], X_train.iloc[val_idx]
        y_tr, y_val = y_train.iloc[train_idx], y_train.iloc[val_idx]

        model = CatBoostClassifier(**params)
        model.fit(X_tr, y_tr,
                  eval_set=(X_val, y_val),
                  early_stopping_rounds=100,
                  verbose=0)

        preds = model.predict_proba(X_val)[:, 1]
        aucs.append(roc_auc_score(y_val, preds))

    return sum(aucs) / len(aucs)

# Run Optuna
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=50)  # increase n_trials for better tuning

print("Best trial:", study.best_trial.params)

# %%
# Extract best parameters
best_params = study.best_trial.params
print("Best trial:", best_params)


# Bagging CatBoost with Best Params
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
val_preds_bagged = np.zeros(len(X_train))

n_bags = 5
for seed in range(n_bags):
    model = CatBoostClassifier(
        **best_params,
        iterations=2000,
        eval_metric="AUC",
        random_seed=seed,
        task_type="GPU",
        verbose=0
    )

    for train_idx, val_idx in kf.split(X_train, y_train):
        X_tr, X_val = X_train.iloc[train_idx], X_train.iloc[val_idx]
        y_tr, y_val = y_train.iloc[train_idx], y_train.iloc[val_idx]

        model.fit(X_tr, y_tr, eval_set=(X_val, y_val), early_stopping_rounds=100, verbose=0)
        val_preds_bagged[val_idx] += model.predict_proba(X_val)[:, 1]

val_preds_bagged /= n_bags
val_auc = roc_auc_score(y_train, val_preds_bagged)
print("Bagged CatBoost Validation AUC:", val_auc)

# Threshold Tuning
best_thresh = 0.5
best_auc = 0

for thresh in np.linspace(0.3, 0.7, 41):  # step of 0.01
    preds = (val_preds_bagged > thresh).astype(int)
    auc = roc_auc_score(y_train, preds)
    if auc > best_auc:
        best_auc = auc
        best_thresh = thresh

print("Best Threshold:", best_thresh, "AUC at threshold:", best_auc)

# %%
from sklearn.metrics import roc_auc_score
import numpy as np

# Optuna Objective Function for LightGBM imbalance handling

def objective(trial):
    params = {
        "objective": "binary",
        "metric": "auc",
        "boosting_type": "gbdt",
        "n_estimators": 10000,  # large, let early stopping cut it down
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3, log=True),
        "num_leaves": trial.suggest_int("num_leaves", 16, 512, log=True),
        "max_depth": trial.suggest_int("max_depth", -1, 16),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 200),
        "subsample": trial.suggest_float("subsample", 0.5, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1.0),
        "reg_lambda": trial.suggest_float("reg_lambda", 1e-8, 10.0, log=True),
        "reg_alpha": trial.suggest_float("reg_alpha", 1e-8, 10.0, log=True),
        "random_state": 42,
        "n_jobs": -1,
        "class_weight": "balanced",
        "device": "gpu"
        
    }

    kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    aucs = []

    for train_idx, val_idx in kf.split(X, y):
        X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
        y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]

        model = lgb.LGBMClassifier(**params)

        model.fit(
            X_train, y_train,
            eval_set=[(X_val, y_val)],
            eval_metric="auc",
            callbacks=[lgb.early_stopping(stopping_rounds=50, verbose=False)]
        )

        y_val_pred = model.predict_proba(X_val)[:, 1]
        y_pred = (y_val_pred > 0.5).astype(int)
        aucs.append(roc_auc_score(y_val, y_pred))

    return np.mean(aucs)

# Run Optuna
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=50, show_progress_bar=True)

print("Best AUC:", study.best_value)
print("Best params:", study.best_params)

# %%
import lightgbm as lgb
import pandas as pd

# Extract best parameters and evaluate on validation set
# Make predictions on test set

best_params = study.best_params
best_params.update({
    "objective": "binary",
    "metric": "auc",
    "boosting_type": "gbdt",
    "n_estimators": 10000,   # use early stopping
    "random_state": 42,
    "class_weight": "balanced",
    "device": "gpu"
})

# Train final LightGBM model
lgb_model = lgb.LGBMClassifier(**best_params)

lgb_model.fit(
    X_train, y_train,
    eval_set=[(X_val, y_val)],
    eval_metric="auc",
    callbacks=[lgb.early_stopping(stopping_rounds=50, verbose=False)]
)

# Predict on test
y_test_lgb_proba = lgb_model.predict_proba(X_test)[:, 1]
y_test_lgb = (y_test_lgb_proba > 0.5).astype(int)

# # Save results
# results_df_lgb = pd.DataFrame({
#     "id": test_ids,
#     "song_popularity": y_test_lgb
# })

# results_df_lgb.to_csv("/kaggle/working/predictions_lgb.csv", index=False)

# %%
from sklearn.metrics import roc_auc_score
import numpy as np
import pandas as pd

# Validation Ensemble of CatBoost and LightGBM with Probabilities

cat_val_proba = cat_model.predict_proba(X_val)[:, 1]
lgb_val_proba = lgb_model.predict_proba(X_val)[:, 1]

# ensemble weights
w_cat, w_lgb = 0.5, 0.5  # equal weights

# ensemble probabilities
val_ensemble_proba = w_cat * cat_val_proba + w_lgb * lgb_val_proba

# compute AUC on probabilities
val_auc = roc_auc_score(y_val, val_ensemble_proba)
print(f"Validation AUC (ensemble): {val_auc:.4f}")

# ---- Final Test Predictions ----
# get test probabilities
cat_test_proba = cat_model.predict_proba(X_test)[:, 1]
lgb_test_proba = lgb_model.predict_proba(X_test)[:, 1]

# ensemble probabilities
test_ensemble_proba = w_cat * cat_test_proba + w_lgb * lgb_test_proba

# convert to binary 0/1 
test_ensemble_pred = (test_ensemble_proba > 0.5).astype(int)

# save to csv 
results_df = pd.DataFrame({
    'id': test_ids,
    'song_popularity': test_ensemble_pred
})
results_df.to_csv('/kaggle/working/predictions_ensemble.csv', index=False)
print("Submission file saved: predictions_ensemble.csv")
